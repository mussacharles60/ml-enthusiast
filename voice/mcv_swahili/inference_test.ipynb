# %%
import pandas as pd
import requests
import os

API_URL = "https://api-inference.huggingface.co/models/mussacharles60/sw_asr_2"
headers = {"Authorization": "Bearer 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"}

def transcribe_audio(filename):
    with open(filename, "rb") as f:
        data = f.read()
    response = requests.post(API_URL, headers=headers, data=data)
    return response.json()

import os

audio_dir = "D:\\Projects\\ml-enthusiast\\voice\\mcv_swahili\\datasets\\audio\\train\\sw_train_0\\sw_train_0"  # Replace with the actual directory path
audio_file_paths = [os.path.join(audio_dir, filename) for filename in os.listdir(audio_dir) if filename.endswith(".mp3")]

# input_voices = [
#     "D:\\Projects\\ml-enthusiast\\voice\\mcv_swahili\\datasets\\audio\\train\\sw_train_0\\sw_train_0\\common_voice_sw_28581660.mp3",
#     "D:\\Projects\\ml-enthusiast\\voice\\mcv_swahili\\datasets\\audio\\train\\sw_train_0\\sw_train_0\\common_voice_sw_28581542.mp3",
#     "D:\\Projects\\ml-enthusiast\\voice\\mcv_swahili\\datasets\\audio\\train\\sw_train_0\\sw_train_0\\common_voice_sw_28661629.mp3",
#     "D:\\Projects\\ml-enthusiast\\voice\\mcv_swahili\\datasets\\audio\\train\\sw_train_0\\sw_train_0\\common_voice_sw_28583464.mp3",
#     "D:\\Projects\\ml-enthusiast\\voice\\mcv_swahili\\datasets\\audio\\train\\sw_train_0\\sw_train_0\\common_voice_sw_28583680.mp3",

#     "D:\\Projects\\ml-enthusiast\\voice\\mcv_swahili\\datasets\\audio\\test\\sw_test_0\\sw_test_0\\common_voice_sw_27729868.mp3",
#     "D:\\Projects\\ml-enthusiast\\voice\\mcv_swahili\\datasets\\audio\\test\\sw_test_0\\sw_test_0\\common_voice_sw_31292631.mp3",
#     "D:\\Projects\\ml-enthusiast\\voice\\mcv_swahili\\datasets\\audio\\test\\sw_test_0\\sw_test_0\\common_voice_sw_35169111.mp3",
#     "D:\\Projects\\ml-enthusiast\\voice\\mcv_swahili\\datasets\\audio\\test\\sw_test_0\\sw_test_0\\common_voice_sw_35169767.mp3",
#     "D:\\Projects\\ml-enthusiast\\voice\\mcv_swahili\\datasets\\audio\\test\\sw_test_0\\sw_test_0\\common_voice_sw_35216686.mp3",

#     "D:\\Projects\\ml-enthusiast\\voice\\mcv_swahili\\datasets\\audio\\test\\sw_test_0\\sw_test_0\\common_voice_sw_35127612.mp3",
#     "D:\\Projects\\ml-enthusiast\\voice\\mcv_swahili\\datasets\\audio\\test\\sw_test_0\\sw_test_0\\common_voice_sw_28259052.mp3",
#     "D:\\Projects\\ml-enthusiast\\voice\\mcv_swahili\\datasets\\audio\\test\\sw_test_0\\sw_test_0\\common_voice_sw_28262255.mp3",
# ]

print(len(audio_file_paths))
# Out:
# 34980

# %%
audio_file_paths

# %%
data = []  # List to store audio path, transcriptions, and ground truth

for i, audio_path in enumerate(audio_file_paths):
    file_name = os.path.basename(audio_path)
    print(f'{i + 1}: audio_path: ', audio_path)
    print(f'{i + 1}: file_name:  ', file_name)
    response = transcribe_audio(audio_path)
    print(f'{i + 1}: response:   ', response)
    transcription = response.get("text", "") 
    if transcription is not None and len(transcription) > 0:
       print('transcription: ', transcription)
       data.append([file_name, transcription])
    print('----------------------------------------------------------')
# Out:
# 1: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28581540.mp3
# 1: file_name:   common_voice_sw_28581540.mp3
# 1: response:    {'text': 'eyekihho shna maa mayae'}
# transcription:  eyekihho shna maa mayae
# ----------------------------------------------------------
# 2: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28581541.mp3
# 2: file_name:   common_voice_sw_28581541.mp3
# 2: response:    {'text': 'bnda a ne i a aishe w  k wana ee nadaa a mnne ayeataiifstta n en'}
# transcription:  bnda a ne i a aishe w  k wana ee nadaa a mnne ayeataiifstta n en
# ----------------------------------------------------------
# 3: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28581542.mp3
# 3: file_name:   common_voice_sw_28581542.mp3
# 3: response:    {'text': 'aa ssa a uwa achimi yaaarai'}
# transcription:  aa ssa a uwa achimi yaaarai
# ----------------------------------------------------------
# 4: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28581652.mp3
# 4: file_name:   common_voice_sw_28581652.mp3
# 4: response:    {'text': 'hiaaa jdwa  wa nagishi hwna uuskiia thaa n va shaaana nuaonhusuh'}
# transcription:  hiaaa jdwa  wa nagishi hwna uuskiia thaa n va shaaana nuaonhusuh
# ----------------------------------------------------------
# 5: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28581654.mp3
# 5: file_name:   common_voice_sw_28581654.mp3
# 5: response:    {'text': 'nihassmwili naai t okana naa mn waaazo'}
# transcription:  nihassmwili naai t okana naa mn waaazo
# ----------------------------------------------------------
# 6: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28581656.mp3
# 6: file_name:   common_voice_sw_28581656.mp3
# 6: response:    {'text': 'etciho  u aiaaan'}
# transcription:  etciho  u aiaaan
# ----------------------------------------------------------
# 7: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28581659.mp3
# 7: file_name:   common_voice_sw_28581659.mp3
# 7: response:    {'text': 'aanainiinckinee ia aniikchwa w wa ina w  echsh a  thmniilii mnwa a  aou  wawaza izhheiiki'}
# transcription:  aanainiinckinee ia aniikchwa w wa ina w  echsh a  thmniilii mnwa a  aou  wawaza izhheiiki
# ----------------------------------------------------------
# 8: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28581660.mp3
# 8: file_name:   common_voice_sw_28581660.mp3
# 8: response:    {'text': 'uwa wkaa nziweei w ww wmo wa shsh ijniw awauiimmaa a aa wfuugajiaa aaeyaijaaljchaa a'}
# transcription:  uwa wkaa nziweei w ww wmo wa shsh ijniw awauiimmaa a aa wfuugajiaa aaeyaijaaljchaa a
# ----------------------------------------------------------
# 9: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28581805.mp3
# 9: file_name:   common_voice_sw_28581805.mp3
# 9: response:    {'text': 'k o lei e inyiko utiine  ol ikei ne tlaadunwwa  wateendyiwa eke'}
# transcription:  k o lei e inyiko utiine  ol ikei ne tlaadunwwa  wateendyiwa eke
# ----------------------------------------------------------
# 10: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28581806.mp3
# 10: file_name:   common_voice_sw_28581806.mp3
# 10: response:    {'text': 'kwwahiii wniiiididd a aee a ai wasaikw wndialsa'}
# transcription:  kwwahiii wniiiididd a aee a ai wasaikw wndialsa
# ----------------------------------------------------------
# 11: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28581807.mp3
# 11: file_name:   common_voice_sw_28581807.mp3
# 11: response:    {'text': 'kkkumekuma immai mia mdi diaanoaublni miiuyaao u itiaala hii iiiwa aw woteiiiiitzt manawk'}
# transcription:  kkkumekuma immai mia mdi diaanoaublni miiuyaao u itiaala hii iiiwa aw woteiiiiitzt manawk
# ----------------------------------------------------------
# 12: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28581810.mp3
# 12: file_name:   common_voice_sw_28581810.mp3
# 12: response:    {'text': 'twalamaaa aaeeia la iudaiumuweena aa alwwaa wa tamaahaaauiiwikijimichaiei awmkdidaa taa aalali'}
# transcription:  twalamaaa aaeeia la iudaiumuweena aa alwwaa wa tamaahaaauiiwikijimichaiei awmkdidaa taa aalali
# ----------------------------------------------------------
# 13: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28581812.mp3
# 13: file_name:   common_voice_sw_28581812.mp3
# 13: response:    {'text': 'tiuhaaassaaak aiffra aaya  kka aitaiiu aa ateoa dahhaliiaeda aatuow'}
# transcription:  tiuhaaassaaak aiffra aaya  kka aitaiiu aa ateoa dahhaliiaeda aatuow
# ----------------------------------------------------------
# 14: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28582296.mp3
# 14: file_name:   common_voice_sw_28582296.mp3
# 14: response:    {'text': 'kkuna  iia minuzea ezesha aabiriuwniabegkianaa kk a k  enyanaaaat acieeea ti  haarakaka'}
# transcription:  kkuna  iia minuzea ezesha aabiriuwniabegkianaa kk a k  enyanaaaat acieeea ti  haarakaka
# ----------------------------------------------------------
# 15: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28582298.mp3
# 15: file_name:   common_voice_sw_28582298.mp3
# 15: response:    {'text': 'maadaizikama kchakula'}
# transcription:  maadaizikama kchakula
# ----------------------------------------------------------
# 16: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28582299.mp3
# 16: file_name:   common_voice_sw_28582299.mp3
# 16: response:    {'text': 'skuutcha gui h ufanmnia uawnma a asizzia wou ukuoiziia auu mnaafa aszamn amnaakakufauorer anah ane'}
# transcription:  skuutcha gui h ufanmnia uawnma a asizzia wou ukuoiziia auu mnaafa aszamn amnaakakufauorer anah ane
# ----------------------------------------------------------
# 17: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28582370.mp3
# 17: file_name:   common_voice_sw_28582370.mp3
# 17: response:    {'text': 'kko waiiw wa w mishimuu mmunhhunachaau la'}
# transcription:  kko waiiw wa w mishimuu mmunhhunachaau la
# ----------------------------------------------------------
# 18: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28582372.mp3
# 18: file_name:   common_voice_sw_28582372.mp3
# 18: response:    {'text': 'piii troufautisanana naasaaa ssa'}
# transcription:  piii troufautisanana naasaaa ssa
# ----------------------------------------------------------
# 19: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28582379.mp3
# 19: file_name:   common_voice_sw_28582379.mp3
# 19: response:    {'text': 'h ao wazinmku wata  wana umhuzeaidireiieaakudawawakee'}
# transcription:  h ao wazinmku wata  wana umhuzeaidireiieaakudawawakee
# ----------------------------------------------------------
# 20: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28582397.mp3
# 20: file_name:   common_voice_sw_28582397.mp3
# 20: response:    {'text': 'pzaaoo iiaaa ukulabeashshadalani tumna hkuu'}
# transcription:  pzaaoo iiaaa ukulabeashshadalani tumna hkuu
# ----------------------------------------------------------
# 21: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28582399.mp3
# 21: file_name:   common_voice_sw_28582399.mp3
# 21: response:    {'text': 'pi yioimekuwa mssisiewateiik no l jiiwaa y to  m yea yahas a  nmmnyeana a ja an  y aanacdkila  aei  na'}
# transcription:  pi yioimekuwa mssisiewateiik no l jiiwaa y to  m yea yahas a  nmmnyeana a ja an  y aanacdkila  aei  na
# ----------------------------------------------------------
# 22: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28582400.mp3
# 22: file_name:   common_voice_sw_28582400.mp3
# 22: response:    {'text': 'cieaki nitaanndka'}
# transcription:  cieaki nitaanndka
# ----------------------------------------------------------
# 23: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28582401.mp3
# 23: file_name:   common_voice_sw_28582401.mp3
# 23: response:    {'text': 'u waananennoni i kiicha kirrefnna neteisi niirlfu'}
# transcription:  u waananennoni i kiicha kirrefnna neteisi niirlfu
# ----------------------------------------------------------
# 24: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28582441.mp3
# 24: file_name:   common_voice_sw_28582441.mp3
# 24: response:    {'text': 'kwkawaaidawa ishina'}
# transcription:  kwkawaaidawa ishina
# ----------------------------------------------------------
# 25: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28582444.mp3
# 25: file_name:   common_voice_sw_28582444.mp3
# 25: response:    {'text': 'neol la katik knye enieaaesaaka tiila bungwwam'}
# transcription:  neol la katik knye enieaaesaaka tiila bungwwam
# ----------------------------------------------------------
# 26: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28582446.mp3
# 26: file_name:   common_voice_sw_28582446.mp3
# 26: response:    {'text': 'mnaenm a lianaza kit o hhahkaauchiuomtoanana iyaya wkubwaa'}
# transcription:  mnaenm a lianaza kit o hhahkaauchiuomtoanana iyaya wkubwaa
# ----------------------------------------------------------
# 27: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28582482.mp3
# 27: file_name:   common_voice_sw_28582482.mp3
# 27: response:    {'text': 'kssi ohisi  unao m apaamwr aini aanyinunlnia na otn maadumn wamahaaii'}
# transcription:  kssi ohisi  unao m apaamwr aini aanyinunlnia na otn maadumn wamahaaii
# ----------------------------------------------------------
# 28: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28582485.mp3
# 28: file_name:   common_voice_sw_28582485.mp3
# 28: response:    {'text': 'kofawtnanaana uwanshh aajio  aadanidaiiilkiidukaa lrasioniitaateoraadiinrakiilaannadaak'}
# transcription:  kofawtnanaana uwanshh aajio  aadanidaiiilkiidukaa lrasioniitaateoraadiinrakiilaannadaak
# ----------------------------------------------------------
# 29: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28582488.mp3
# 29: file_name:   common_voice_sw_28582488.mp3
# 29: response:    {'text': 'kto utta m uwiimkiautu hiuina num mw adiiwahaa nrakkakikwhahuumoishia nara wwh i'}
# transcription:  kto utta m uwiimkiautu hiuina num mw adiiwahaa nrakkakikwhahuumoishia nara wwh i
# ----------------------------------------------------------
# 30: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28582507.mp3
# 30: file_name:   common_voice_sw_28582507.mp3
# 30: response:    {'text': 'kehaai hivy a ito za  waakeo dumi iy e umuwnileeze ae n'}
# transcription:  kehaai hivy a ito za  waakeo dumi iy e umuwnileeze ae n
# ----------------------------------------------------------
# 31: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28582508.mp3
# 31: file_name:   common_voice_sw_28582508.mp3
# 31: response:    {'text': 'aahanayasshimiwo atsa eu uu smwa  ananisaana kanmmw maaiif'}
# transcription:  aahanayasshimiwo atsa eu uu smwa  ananisaana kanmmw maaiif
# ----------------------------------------------------------
# 32: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28582509.mp3
# 32: file_name:   common_voice_sw_28582509.mp3
# 32: response:    {'text': 'kaatikaw maume oa no awwa aurid a m aao alio wchini namkannidhtataa lao'}
# transcription:  kaatikaw maume oa no awwa aurid a m aao alio wchini namkannidhtataa lao
# ----------------------------------------------------------
# 33: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28582510.mp3
# 33: file_name:   common_voice_sw_28582510.mp3
# 33: response:    {'text': 'kalendlaedaoun tegeinee n kiukioa wa haaanagaamui isiianodjanana nw tasaabwa'}
# transcription:  kalendlaedaoun tegeinee n kiukioa wa haaanagaamui isiianodjanana nw tasaabwa
# ----------------------------------------------------------
# 34: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28582542.mp3
# 34: file_name:   common_voice_sw_28582542.mp3
# 34: response:    {'text': 'ena haiil  ita addinnchikawmana mosukawu'}
# transcription:  ena haiil  ita addinnchikawmana mosukawu
# ----------------------------------------------------------
# 35: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28582543.mp3
# 35: file_name:   common_voice_sw_28582543.mp3
# 35: response:    {'text': 'ia a wseajeimm ojba aanichini yaara  wcsi n'}
# transcription:  ia a wseajeimm ojba aanichini yaara  wcsi n
# ----------------------------------------------------------
# 36: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28582545.mp3
# 36: file_name:   common_voice_sw_28582545.mp3
# 36: response:    {'text': 'napa tikaa oteunnia a nia'}
# transcription:  napa tikaa oteunnia a nia
# ----------------------------------------------------------
# 37: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28582546.mp3
# 37: file_name:   common_voice_sw_28582546.mp3
# 37: response:    {'text': 'kh w waktnjmiwa rna a eza w yyi kuwuoumma  mmaa  mmnanalafwiriku eumiubjaauwa apeeepka watwuiayjiimginia'}
# transcription:  kh w waktnjmiwa rna a eza w yyi kuwuoumma  mmaa  mmnanalafwiriku eumiubjaauwa apeeepka watwuiayjiimginia
# ----------------------------------------------------------
# 38: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28582547.mp3
# 38: file_name:   common_voice_sw_28582547.mp3
# 38: response:    {'text': 'cnchinia wusss leilla kriitiml la otuola yecchu wae hct att  ni'}
# transcription:  cnchinia wusss leilla kriitiml la otuola yecchu wae hct att  ni
# ----------------------------------------------------------
# 39: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28582577.mp3
# 39: file_name:   common_voice_sw_28582577.mp3
# 39: response:    {'text': 'iileianzishha  ainana m mkpnen maa a uta aummmmwonjalatieklannan hie ndoo'}
# transcription:  iileianzishha  ainana m mkpnen maa a uta aummmmwonjalatieklannan hie ndoo
# ----------------------------------------------------------
# 40: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28582578.mp3
# 40: file_name:   common_voice_sw_28582578.mp3
# 40: response:    {'text': 'ku nyingi znaweza rukndane'}
# transcription:  ku nyingi znaweza rukndane
# ----------------------------------------------------------
# 41: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28582579.mp3
# 41: file_name:   common_voice_sw_28582579.mp3
# 41: response:    {'text': 'uila nmdege hasa na awaduutpyya'}
# transcription:  uila nmdege hasa na awaduutpyya
# ----------------------------------------------------------
# 42: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28582580.mp3
# 42: file_name:   common_voice_sw_28582580.mp3
# 42: response:    {'text': 'ka muutillaeiz  iiiiika mwwu ja ket ilvhvyaaz viyahalakatii jaza mna zaamakaza'}
# transcription:  ka muutillaeiz  iiiiika mwwu ja ket ilvhvyaaz viyahalakatii jaza mna zaamakaza
# ----------------------------------------------------------
# 43: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28582581.mp3
# 43: file_name:   common_voice_sw_28582581.mp3
# 43: response:    {'text': 'kiy ni mdiwa me w duawud e kihiuv cechia ailetikchauwaki ko chaanarov'}
# transcription:  kiy ni mdiwa me w duawud e kihiuv cechia ailetikchauwaki ko chaanarov
# ----------------------------------------------------------
# 44: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28582600.mp3
# 44: file_name:   common_voice_sw_28582600.mp3
# 44: response:    {'text': 'jina l ihii nd aa iilieakuuzalali wa m ljeatalal chiui'}
# transcription:  jina l ihii nd aa iilieakuuzalali wa m ljeatalal chiui
# ----------------------------------------------------------
# 45: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28582602.mp3
# 45: file_name:   common_voice_sw_28582602.mp3
# 45: response:    {'text': 'taleilzchomnnhuzia a uhaala zzakeikeimia ndaa niaach ma haae'}
# transcription:  taleilzchomnnhuzia a uhaala zzakeikeimia ndaa niaach ma haae
# ----------------------------------------------------------
# 46: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28582604.mp3
# 46: file_name:   common_voice_sw_28582604.mp3
# 46: response:    {'text': 'hola wado omatuamwaognaee'}
# transcription:  hola wado omatuamwaognaee
# ----------------------------------------------------------
# 47: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28582607.mp3
# 47: file_name:   common_voice_sw_28582607.mp3
# 47: response:    {'text': 'fii amal  ay y aleantia laastamiwlsi ykenye ealat ana an annmnsiki wakitananii alya n'}
# transcription:  fii amal  ay y aleantia laastamiwlsi ykenye ealat ana an annmnsiki wakitananii alya n
# ----------------------------------------------------------
# 48: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28582609.mp3
# 48: file_name:   common_voice_sw_28582609.mp3
# 48: response:    {'text': 'atcuu ninaarsaana'}
# transcription:  atcuu ninaarsaana
# ----------------------------------------------------------
# 49: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28582728.mp3
# 49: file_name:   common_voice_sw_28582728.mp3
# 49: response:    {'text': 'innachia  wmm njaawatifna umaja uilayay'}
# transcription:  innachia  wmm njaawatifna umaja uilayay
# ----------------------------------------------------------
# 50: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28582733.mp3
# 50: file_name:   common_voice_sw_28582733.mp3
# 50: response:    {'text': 'eucheezakam kig  waoemsha mbulia yajii'}
# transcription:  eucheezakam kig  waoemsha mbulia yajii
# ----------------------------------------------------------
# 51: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28582735.mp3
# 51: file_name:   common_voice_sw_28582735.mp3
# 51: response:    {'text': 'wakcalamu wa nenotoeumyeen cho  ana icchara oleeza  lio'}
# transcription:  wakcalamu wa nenotoeumyeen cho  ana icchara oleeza  lio
# ----------------------------------------------------------
# 52: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28582797.mp3
# 52: file_name:   common_voice_sw_28582797.mp3
# 52: response:    {'text': 'iukkti a aa kazini nash atrikii aaat yakamkhi a wtikjijuo w'}
# transcription:  iukkti a aa kazini nash atrikii aaat yakamkhi a wtikjijuo w
# ----------------------------------------------------------
# 53: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28582799.mp3
# 53: file_name:   common_voice_sw_28582799.mp3
# 53: response:    {'text': 'siil l a tnlicalaticatt anistatl  ahnktiiiik'}
# transcription:  siil l a tnlicalaticatt anistatl  ahnktiiiik
# ----------------------------------------------------------
# 54: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28582810.mp3
# 54: file_name:   common_voice_sw_28582810.mp3
# 54: response:    {'text': 'ouok aniju na mbjia mmekse'}
# transcription:  ouok aniju na mbjia mmekse
# ----------------------------------------------------------
# 55: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28582812.mp3
# 55: file_name:   common_voice_sw_28582812.mp3
# 55: response:    {'text': 'eizio teyii isii he  enye ny sthaaeni eo  lakimwinisitw p mona atiwa palnmnewamu w ngglaa no'}
# transcription:  eizio teyii isii he  enye ny sthaaeni eo  lakimwinisitw p mona atiwa palnmnewamu w ngglaa no
# ----------------------------------------------------------
# 56: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28582865.mp3
# 56: file_name:   common_voice_sw_28582865.mp3
# 56: response:    {'text': 'ainenamna a ae na kiyna chaubahali uo uthia naisaa na kt kon mwan aji hadienii nne'}
# transcription:  ainenamna a ae na kiyna chaubahali uo uthia naisaa na kt kon mwan aji hadienii nne
# ----------------------------------------------------------
# 57: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28582867.mp3
# 57: file_name:   common_voice_sw_28582867.mp3
# 57: response:    {'text': 'w amfaa awaaoinizetkana ukungizwaurefuw w a way na n mfwuuriaona enee'}
# transcription:  w amfaa awaaoinizetkana ukungizwaurefuw w a way na n mfwuuriaona enee
# ----------------------------------------------------------
# 58: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28582868.mp3
# 58: file_name:   common_voice_sw_28582868.mp3
# 58: response:    {'text': 'urrut wakisu wavyetii udiuwwajaamondaneromajakuwwviti'}
# transcription:  urrut wakisu wavyetii udiuwwajaamondaneromajakuwwviti
# ----------------------------------------------------------
# 59: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28582870.mp3
# 59: file_name:   common_voice_sw_28582870.mp3
# 59: response:    {'text': 's wataubagu uufsannaananaa w  wilddio ukaaeuonilenine  wanachananne wekatiln aaaaan'}
# transcription:  s wataubagu uufsannaananaa w  wilddio ukaaeuonilenine  wanachananne wekatiln aaaaan
# ----------------------------------------------------------
# 60: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28582948.mp3
# 60: file_name:   common_voice_sw_28582948.mp3
# 60: response:    {'text': 'ima ajiiiaazii ka a naenyikaalyanaakn andii amt owa wna at maabahaahakianii'}
# transcription:  ima ajiiiaazii ka a naenyikaalyanaakn andii amt owa wna at maabahaahakianii
# ----------------------------------------------------------
# 61: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28582949.mp3
# 61: file_name:   common_voice_sw_28582949.mp3
# 61: response:    {'text': 'tu uniimmwadjakaihaauhusikbwwakabikatiuahurliioh'}
# transcription:  tu uniimmwadjakaihaauhusikbwwakabikatiuahurliioh
# ----------------------------------------------------------
# 62: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28582950.mp3
# 62: file_name:   common_voice_sw_28582950.mp3
# 62: response:    {'text': 'auuka  enaichin  wanawanatikat oliki na utooothhi kathnia wataaka ati'}
# transcription:  auuka  enaichin  wanawanatikat oliki na utooothhi kathnia wataaka ati
# ----------------------------------------------------------
# 63: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28582952.mp3
# 63: file_name:   common_voice_sw_28582952.mp3
# 63: response:    {'text': 'ranis aka ni nyruananyeusi'}
# transcription:  ranis aka ni nyruananyeusi
# ----------------------------------------------------------
# 64: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28582993.mp3
# 64: file_name:   common_voice_sw_28582993.mp3
# 64: response:    {'text': 'pnnhaishhammti awaiidaakawakati owo hyli kowana gmu una ouii'}
# transcription:  pnnhaishhammti awaiidaakawakati owo hyli kowana gmu una ouii
# ----------------------------------------------------------
# 65: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28582995.mp3
# 65: file_name:   common_voice_sw_28582995.mp3
# 65: response:    {'text': 'tai yidegekrha sa ama aangei e sonantwa mtili'}
# transcription:  tai yidegekrha sa ama aangei e sonantwa mtili
# ----------------------------------------------------------
# 66: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28582996.mp3
# 66: file_name:   common_voice_sw_28582996.mp3
# 66: response:    {'text': 'u abu ayana kieye ay hhajjiemu haham mnuiulnmusht aiakka ailii koaanujieashssh lawa uaa miyyaaasarasuo wkammaalashuir i'}
# transcription:  u abu ayana kieye ay hhajjiemu haham mnuiulnmusht aiakka ailii koaanujieashssh lawa uaa miyyaaasarasuo wkammaalashuir i
# ----------------------------------------------------------
# 67: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28582997.mp3
# 67: file_name:   common_voice_sw_28582997.mp3
# 67: response:    {'text': 'pia yileanin chmcheaizua vavutchgakga ne tchia iralkitawk oarawkztiingmi'}
# transcription:  pia yileanin chmcheaizua vavutchgakga ne tchia iralkitawk oarawkztiingmi
# ----------------------------------------------------------
# 68: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28583091.mp3
# 68: file_name:   common_voice_sw_28583091.mp3
# 68: response:    {'text': 'menyea siile yasilr aaallshi huo kammmm aonaki aare'}
# transcription:  menyea siile yasilr aaallshi huo kammmm aonaki aare
# ----------------------------------------------------------
# 69: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28583095.mp3
# 69: file_name:   common_voice_sw_28583095.mp3
# 69: response:    {'text': 'imat anchchi yakk alliawana'}
# transcription:  imat anchchi yakk alliawana
# ----------------------------------------------------------
# 70: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28583098.mp3
# 70: file_name:   common_voice_sw_28583098.mp3
# 70: response:    {'text': 'enyeji ni hatwa wakaamila llaakiuy'}
# transcription:  enyeji ni hatwa wakaamila llaakiuy
# ----------------------------------------------------------
# 71: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28583151.mp3
# 71: file_name:   common_voice_sw_28583151.mp3
# 71: response:    {'text': 'itaanguka e anaish nw waaawkaet likiena waluuheyriiikannwaniaa atft mhhe adii mn'}
# transcription:  itaanguka e anaish nw waaawkaet likiena waluuheyriiikannwaniaa atft mhhe adii mn
# ----------------------------------------------------------
# 72: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28583152.mp3
# 72: file_name:   common_voice_sw_28583152.mp3
# 72: response:    {'text': 'bjoldan  luounubawwa ko ussko ammkursheirii athan'}
# transcription:  bjoldan  luounubawwa ko ussko ammkursheirii athan
# ----------------------------------------------------------
# 73: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28583153.mp3
# 73: file_name:   common_voice_sw_28583153.mp3
# 73: response:    {'text': 'anasea woamawaii fia y achikawa esa ninu muma a jegmw ula kibwa niniuni'}
# transcription:  anasea woamawaii fia y achikawa esa ninu muma a jegmw ula kibwa niniuni
# ----------------------------------------------------------
# 74: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28583197.mp3
# 74: file_name:   common_voice_sw_28583197.mp3
# 74: response:    {'text': 'na atoalnion  anctii mi l teenhnisalanianat'}
# transcription:  na atoalnion  anctii mi l teenhnisalanianat
# ----------------------------------------------------------
# 75: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28583204.mp3
# 75: file_name:   common_voice_sw_28583204.mp3
# 75: response:    {'text': 'eenine e jee   ni ln tu ni yi y aw tihaduhuvya na mndiia haana lukana n na l neeldi'}
# transcription:  eenine e jee   ni ln tu ni yi y aw tihaduhuvya na mndiia haana lukana n na l neeldi
# ----------------------------------------------------------
# 76: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28583275.mp3
# 76: file_name:   common_voice_sw_28583275.mp3
# 76: response:    {'text': 'fkshndakisidin iyaakil ma akama waruhushha'}
# transcription:  fkshndakisidin iyaakil ma akama waruhushha
# ----------------------------------------------------------
# 77: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28583276.mp3
# 77: file_name:   common_voice_sw_28583276.mp3
# 77: response:    {'text': 'lukha a zackidub a ut nt ti naata dia mbalim aelnesza ai mgmai jan'}
# transcription:  lukha a zackidub a ut nt ti naata dia mbalim aelnesza ai mgmai jan
# ----------------------------------------------------------
# 78: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28583277.mp3
# 78: file_name:   common_voice_sw_28583277.mp3
# 78: response:    {'text': 'dmagaananana  at egk atika waakuu lie hwatammaauee alu wami'}
# transcription:  dmagaananana  at egk atika waakuu lie hwatammaauee alu wami
# ----------------------------------------------------------
# 79: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28583278.mp3
# 79: file_name:   common_voice_sw_28583278.mp3
# 79: response:    {'text': 'lieonoaicacha na walwaubaaa kii'}
# transcription:  lieonoaicacha na walwaubaaa kii
# ----------------------------------------------------------
# 80: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28583279.mp3
# 80: file_name:   common_voice_sw_28583279.mp3
# 80: response:    {'text': 'uw aohu weza kko amawdafuuoo iillam'}
# transcription:  uw aohu weza kko amawdafuuoo iillam
# ----------------------------------------------------------
# 81: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28583338.mp3
# 81: file_name:   common_voice_sw_28583338.mp3
# 81: response:    {'text': 'ikaaszivjilo wacha vijawailiamvina'}
# transcription:  ikaaszivjilo wacha vijawailiamvina
# ----------------------------------------------------------
# 82: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28583340.mp3
# 82: file_name:   common_voice_sw_28583340.mp3
# 82: response:    {'text': 'haddjune kra n mnene urnsoriaayao  ilaattankaraa awoanaichin a ammawataatif'}
# transcription:  haddjune kra n mnene urnsoriaayao  ilaattankaraa awoanaichin a ammawataatif
# ----------------------------------------------------------
# 83: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28583342.mp3
# 83: file_name:   common_voice_sw_28583342.mp3
# 83: response:    {'text': 'i  muuunee uhurtu miarana andlizmsieatik kasa naaa ahakea upigajiikpicha'}
# transcription:  i  muuunee uhurtu miarana andlizmsieatik kasa naaa ahakea upigajiikpicha
# ----------------------------------------------------------
# 84: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28583344.mp3
# 84: file_name:   common_voice_sw_28583344.mp3
# 84: response:    {'text': 'aliyew ecuchezatintefca malechia'}
# transcription:  aliyew ecuchezatintefca malechia
# ----------------------------------------------------------
# 85: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28583369.mp3
# 85: file_name:   common_voice_sw_28583369.mp3
# 85: response:    {'text': 'nchis nist anyyingi htu mmi natnalnak mekiehtkaamssinimmwaw sa'}
# transcription:  nchis nist anyyingi htu mmi natnalnak mekiehtkaamssinimmwaw sa
# ----------------------------------------------------------
# 86: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28583370.mp3
# 86: file_name:   common_voice_sw_28583370.mp3
# 86: response:    {'text': 'tuainenza k inidbdgjsaijio aw w trot k ia atrnishen'}
# transcription:  tuainenza k inidbdgjsaijio aw w trot k ia atrnishen
# ----------------------------------------------------------
# 87: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28583371.mp3
# 87: file_name:   common_voice_sw_28583371.mp3
# 87: response:    {'text': 'nyao nza ni ndeffu'}
# transcription:  nyao nza ni ndeffu
# ----------------------------------------------------------
# 88: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28583411.mp3
# 88: file_name:   common_voice_sw_28583411.mp3
# 88: response:    {'text': 'kkaieliiaazauhishrik a tiecamashnga mna auim nawucsaanwama kia wamt ao'}
# transcription:  kkaieliiaazauhishrik a tiecamashnga mna auim nawucsaanwama kia wamt ao
# ----------------------------------------------------------
# 89: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28583418.mp3
# 89: file_name:   common_voice_sw_28583418.mp3
# 89: response:    {'text': 'waaeno walieenzisshawashaa ma a mio wanaueta waoum a oao ok balalaairikaa'}
# transcription:  waaeno walieenzisshawashaa ma a mio wanaueta waoum a oao ok balalaairikaa
# ----------------------------------------------------------
# 90: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28583420.mp3
# 90: file_name:   common_voice_sw_28583420.mp3
# 90: response:    {'text': 'haie amach ie ankit dyininchi  aeki anhajjuudic aano nkha'}
# transcription:  haie amach ie ankit dyininchi  aeki anhajjuudic aano nkha
# ----------------------------------------------------------
# 91: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28583423.mp3
# 91: file_name:   common_voice_sw_28583423.mp3
# 91: response:    {'text': 'wafwa timm uhmunielo'}
# transcription:  wafwa timm uhmunielo
# ----------------------------------------------------------
# 92: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28583460.mp3
# 92: file_name:   common_voice_sw_28583460.mp3
# 92: response:    {'text': 'ka attiya unusu keonvulnna mnennoenmyennulumpaasicaaa ela n'}
# transcription:  ka attiya unusu keonvulnna mnennoenmyennulumpaasicaaa ela n
# ----------------------------------------------------------
# 93: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28583461.mp3
# 93: file_name:   common_voice_sw_28583461.mp3
# 93: response:    {'text': 'manen uffaywoa nn asiylbi'}
# transcription:  manen uffaywoa nn asiylbi
# ----------------------------------------------------------
# 94: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28583462.mp3
# 94: file_name:   common_voice_sw_28583462.mp3
# 94: response:    {'text': 'tienik katektkam ochchi wa mw t wa mmaawozur eat mna wteei'}
# transcription:  tienik katektkam ochchi wa mw t wa mmaawozur eat mna wteei
# ----------------------------------------------------------
# 95: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28583463.mp3
# 95: file_name:   common_voice_sw_28583463.mp3
# 95: response:    {'text': 'akila  lu ghauawanana  mnenanopaw taun jinensia awaaddika amwaneno'}
# transcription:  akila  lu ghauawanana  mnenanopaw taun jinensia awaaddika amwaneno
# ----------------------------------------------------------
# 96: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28583464.mp3
# 96: file_name:   common_voice_sw_28583464.mp3
# 96: response:    {'text': 'wliolaeuchezaatika ngielaenznzaniaa'}
# transcription:  wliolaeuchezaatika ngielaenznzaniaa
# ----------------------------------------------------------
# 97: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28583504.mp3
# 97: file_name:   common_voice_sw_28583504.mp3
# 97: response:    {'text': 'a dobadiilk oatiao aiteendaadmji wak ladili uuandeeea kuta mulioa a'}
# transcription:  a dobadiilk oatiao aiteendaadmji wak ladili uuandeeea kuta mulioa a
# ----------------------------------------------------------
# 98: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28583507.mp3
# 98: file_name:   common_voice_sw_28583507.mp3
# 98: response:    {'text': 'raltiykkchis za tcinnmlataeiakka yargeniian naai'}
# transcription:  raltiykkchis za tcinnmlataeiakka yargeniian naai
# ----------------------------------------------------------
# 99: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28583511.mp3
# 99: file_name:   common_voice_sw_28583511.mp3
# 99: response:    {'text': 'ktaahuokaranichimi a wanaawkaco wriidkna waadoksiikama  maatfu maidiimi'}
# transcription:  ktaahuokaranichimi a wanaawkaco wriidkna waadoksiikama  maatfu maidiimi
# ----------------------------------------------------------
# 100: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28583564.mp3
# 100: file_name:   common_voice_sw_28583564.mp3
# 100: response:    {'text': 'aliriiaku wanaawtiotoliiw'}
# transcription:  aliriiaku wanaawtiotoliiw
# ----------------------------------------------------------
# 101: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28583565.mp3
# 101: file_name:   common_voice_sw_28583565.mp3
# 101: response:    {'text': 'baaada akiforcha atea ka inoilaldofwoeo'}
# transcription:  baaada akiforcha atea ka inoilaldofwoeo
# ----------------------------------------------------------
# 102: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28583567.mp3
# 102: file_name:   common_voice_sw_28583567.mp3
# 102: response:    {'text': 'odetkreiam huuhung uk na  jiadhuhmmnaaen a awaosssdo  are yad dindi y a r husiengresanawaufolraansa'}
# transcription:  odetkreiam huuhung uk na  jiadhuhmmnaaen a awaosssdo  are yad dindi y a r husiengresanawaufolraansa
# ----------------------------------------------------------
# 103: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28583583.mp3
# 103: file_name:   common_voice_sw_28583583.mp3
# 103: response:    {'text': 'mnmji ko nn muniiukaa'}
# transcription:  mnmji ko nn muniiukaa
# ----------------------------------------------------------
# 104: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28583584.mp3
# 104: file_name:   common_voice_sw_28583584.mp3
# 104: response:    {'text': 'kjeendnrileisa ak wanz aza iloabawhadaasi n uoduoufwa ta whuruuukwauualansia'}
# transcription:  kjeendnrileisa ak wanz aza iloabawhadaasi n uoduoufwa ta whuruuukwauualansia
# ----------------------------------------------------------
# 105: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28583585.mp3
# 105: file_name:   common_voice_sw_28583585.mp3
# 105: response:    {'text': 'katkatiais o autokiaatila tuf uawatiika stfiholei a tsilaniii'}
# transcription:  katkatiais o autokiaatila tuf uawatiika stfiholei a tsilaniii
# ----------------------------------------------------------
# 106: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28583586.mp3
# 106: file_name:   common_voice_sw_28583586.mp3
# 106: response:    {'text': 'kuuoca wanz chegecha lwa macha ovs'}
# transcription:  kuuoca wanz chegecha lwa macha ovs
# ----------------------------------------------------------
# 107: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28583587.mp3
# 107: file_name:   common_voice_sw_28583587.mp3
# 107: response:    {'text': 'kaeliuciliahilsabhadichi ha ais in na afiihi haya a leniewa wa wimiwe e'}
# transcription:  kaeliuciliahilsabhadichi ha ais in na afiihi haya a leniewa wa wimiwe e
# ----------------------------------------------------------
# 108: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28583639.mp3
# 108: file_name:   common_voice_sw_28583639.mp3
# 108: response:    {'text': 'imajika  aonama dawwnaekie anamiukeimnena adumaaw ni nnme'}
# transcription:  imajika  aonama dawwnaekie anamiukeimnena adumaaw ni nnme
# ----------------------------------------------------------
# 109: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28583641.mp3
# 109: file_name:   common_voice_sw_28583641.mp3
# 109: response:    {'text': 'kkkabla yawurjiluann  ela biya ualaaay'}
# transcription:  kkkabla yawurjiluann  ela biya ualaaay
# ----------------------------------------------------------
# 110: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28583643.mp3
# 110: file_name:   common_voice_sw_28583643.mp3
# 110: response:    {'text': 'kccichaabu tcheijjin  ala   ka apatian analatankilya aiani cokkatikaa knn ol aaka e'}
# transcription:  kccichaabu tcheijjin  ala   ka apatian analatankilya aiani cokkatikaa knn ol aaka e
# ----------------------------------------------------------
# 111: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28583674.mp3
# 111: file_name:   common_voice_sw_28583674.mp3
# 111: response:    {'text': 'lugha meeikairibia a to  ia kashahi rarabuunidili'}
# transcription:  lugha meeikairibia a to  ia kashahi rarabuunidili
# ----------------------------------------------------------
# 112: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28583675.mp3
# 112: file_name:   common_voice_sw_28583675.mp3
# 112: response:    {'text': 'dddta ea adbaardu oaa hatu mmchhiii ktcuui tukiieau heidiy  n'}
# transcription:  dddta ea adbaardu oaa hatu mmchhiii ktcuui tukiieau heidiy  n
# ----------------------------------------------------------
# 113: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28583677.mp3
# 113: file_name:   common_voice_sw_28583677.mp3
# 113: response:    {'text': 'kujpaandre a  agharribi ni maai watsi'}
# transcription:  kujpaandre a  agharribi ni maai watsi
# ----------------------------------------------------------
# 114: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28583680.mp3
# 114: file_name:   common_voice_sw_28583680.mp3
# 114: response:    {'text': 'kaaiikcshuau ma uustiwau utwa a muhiikihnawjihiushcch emnnaju k mu kah i nakidnam anan a ma  ahari'}
# transcription:  kaaiikcshuau ma uustiwau utwa a muhiikihnawjihiushcch emnnaju k mu kah i nakidnam anan a ma  ahari
# ----------------------------------------------------------
# 115: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28583681.mp3
# 115: file_name:   common_voice_sw_28583681.mp3
# 115: response:    {'text': 'al ikuwa n n n enaldolukatidkeita ii ksaiwwi'}
# transcription:  al ikuwa n n n enaldolukatidkeita ii ksaiwwi
# ----------------------------------------------------------
# 116: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28583732.mp3
# 116: file_name:   common_voice_sw_28583732.mp3
# 116: response:    {'text': 'ih liyo ala yansisha ammidkii y a iwananza  abaadellil'}
# transcription:  ih liyo ala yansisha ammidkii y a iwananza  abaadellil
# ----------------------------------------------------------
# 117: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28583734.mp3
# 117: file_name:   common_voice_sw_28583734.mp3
# 117: response:    {'text': 'naatedei me aka akl aadaatbla nchhii'}
# transcription:  naatedei me aka akl aadaatbla nchhii
# ----------------------------------------------------------
# 118: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28583736.mp3
# 118: file_name:   common_voice_sw_28583736.mp3
# 118: response:    {'text': 'taaggza maanidnb haalahii njia u za mmwaniziimia naikianatahifua'}
# transcription:  taaggza maanidnb haalahii njia u za mmwaniziimia naikianatahifua
# ----------------------------------------------------------
# 119: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28584065.mp3
# 119: file_name:   common_voice_sw_28584065.mp3
# 119: response:    {'text': 'zz ahidrithirrtzinn honziinanaz churika tianaa k hadriaa nch an nan khdrinyi ku u'}
# transcription:  zz ahidrithirrtzinn honziinanaz churika tianaa k hadriaa nch an nan khdrinyi ku u
# ----------------------------------------------------------
# 120: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28584066.mp3
# 120: file_name:   common_voice_sw_28584066.mp3
# 120: response:    {'text': 'i ni nkb uuliiko  wagaanininmuginneds ta umuiloa ana daa mu'}
# transcription:  i ni nkb uuliiko  wagaanininmuginneds ta umuiloa ana daa mu
# ----------------------------------------------------------
# 121: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28584079.mp3
# 121: file_name:   common_voice_sw_28584079.mp3
# 121: response:    {'text': 'rikanashaiien tha l leskee aizamnatesuienaw wwaaa udwawaaawana'}
# ...
# 710: file_name:   common_voice_sw_28666586.mp3
# 710: response:    {'error': 'Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}
# ----------------------------------------------------------
# 711: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28666587.mp3
# 711: file_name:   common_voice_sw_28666587.mp3
# 711: response:    {'error': 'Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}
# ----------------------------------------------------------
# 712: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28666588.mp3
# 712: file_name:   common_voice_sw_28666588.mp3
# 712: response:    {'error': 'Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}
# ----------------------------------------------------------
# 713: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28666599.mp3
# 713: file_name:   common_voice_sw_28666599.mp3
# 713: response:    {'error': 'Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}
# ----------------------------------------------------------
# 714: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28666600.mp3
# 714: file_name:   common_voice_sw_28666600.mp3
# 714: response:    {'error': 'Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}
# ----------------------------------------------------------
# 715: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28666601.mp3
# 715: file_name:   common_voice_sw_28666601.mp3
# 715: response:    {'error': 'Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}
# ----------------------------------------------------------
# 716: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28666603.mp3
# 716: file_name:   common_voice_sw_28666603.mp3
# 716: response:    {'error': 'Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}
# ----------------------------------------------------------
# 717: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28666604.mp3
# 717: file_name:   common_voice_sw_28666604.mp3
# 717: response:    {'error': 'Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}
# ----------------------------------------------------------
# 718: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28666605.mp3
# 718: file_name:   common_voice_sw_28666605.mp3
# 718: response:    {'error': 'Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}
# ----------------------------------------------------------
# 719: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28666606.mp3
# 719: file_name:   common_voice_sw_28666606.mp3
# 719: response:    {'error': 'Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}
# ----------------------------------------------------------
# 720: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28666607.mp3
# 720: file_name:   common_voice_sw_28666607.mp3
# 720: response:    {'error': 'Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}
# ----------------------------------------------------------
# 721: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28666611.mp3
# 721: file_name:   common_voice_sw_28666611.mp3
# 721: response:    {'error': 'Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}
# ----------------------------------------------------------
# 722: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28666614.mp3
# 722: file_name:   common_voice_sw_28666614.mp3
# 722: response:    {'error': 'Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}
# ----------------------------------------------------------
# 723: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28666615.mp3
# 723: file_name:   common_voice_sw_28666615.mp3
# 723: response:    {'error': 'Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}
# ----------------------------------------------------------
# 724: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28666621.mp3
# 724: file_name:   common_voice_sw_28666621.mp3
# 724: response:    {'error': 'Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}
# ----------------------------------------------------------
# 725: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28666627.mp3
# 725: file_name:   common_voice_sw_28666627.mp3
# 725: response:    {'error': 'Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}
# ----------------------------------------------------------
# 726: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28666628.mp3
# 726: file_name:   common_voice_sw_28666628.mp3
# 726: response:    {'error': 'Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}
# ----------------------------------------------------------
# 727: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28666639.mp3
# 727: file_name:   common_voice_sw_28666639.mp3
# 727: response:    {'error': 'Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}
# ----------------------------------------------------------
# 728: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28666640.mp3
# 728: file_name:   common_voice_sw_28666640.mp3
# 728: response:    {'error': 'Rate limit reached. You reached free usage limit (reset hourly). Please subscribe to a plan at https://huggingface.co/pricing to use the API at this rate'}
# ----------------------------------------------------------
# 729: audio_path:  D:\Projects\ml-enthusiast\voice\mcv_swahili\datasets\audio\train\sw_train_0\sw_train_0\common_voice_sw_28666641.mp3
# 729: file_name:   common_voice_sw_28666641.mp3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\Projects\ml-enthusiast\voice\mcv_swahili\inference_test.ipynb Cell 3 line 7
#       <a href='vscode-notebook-cell:/d%3A/Projects/ml-enthusiast/voice/mcv_swahili/inference_test.ipynb#W2sZmlsZQ%3D%3D?line=4'>5</a> print(f'{i + 1}: audio_path: ', audio_path)
#       <a href='vscode-notebook-cell:/d%3A/Projects/ml-enthusiast/voice/mcv_swahili/inference_test.ipynb#W2sZmlsZQ%3D%3D?line=5'>6</a> print(f'{i + 1}: file_name:  ', file_name)
# ----> <a href='vscode-notebook-cell:/d%3A/Projects/ml-enthusiast/voice/mcv_swahili/inference_test.ipynb#W2sZmlsZQ%3D%3D?line=6'>7</a> response = transcribe_audio(audio_path)
#       <a href='vscode-notebook-cell:/d%3A/Projects/ml-enthusiast/voice/mcv_swahili/inference_test.ipynb#W2sZmlsZQ%3D%3D?line=7'>8</a> print(f'{i + 1}: response:   ', response)
#       <a href='vscode-notebook-cell:/d%3A/Projects/ml-enthusiast/voice/mcv_swahili/inference_test.ipynb#W2sZmlsZQ%3D%3D?line=8'>9</a> transcription = response.get("text", "")
#
# d:\Projects\ml-enthusiast\voice\mcv_swahili\inference_test.ipynb Cell 3 line 1
#       <a href='vscode-notebook-cell:/d%3A/Projects/ml-enthusiast/voice/mcv_swahili/inference_test.ipynb#W2sZmlsZQ%3D%3D?line=8'>9</a> with open(filename, "rb") as f:
#      <a href='vscode-notebook-cell:/d%3A/Projects/ml-enthusiast/voice/mcv_swahili/inference_test.ipynb#W2sZmlsZQ%3D%3D?line=9'>10</a>     data = f.read()
# ---> <a href='vscode-notebook-cell:/d%3A/Projects/ml-enthusiast/voice/mcv_swahili/inference_test.ipynb#W2sZmlsZQ%3D%3D?line=10'>11</a> response = requests.post(API_URL, headers=headers, data=data)
#      <a href='vscode-notebook-cell:/d%3A/Projects/ml-enthusiast/voice/mcv_swahili/inference_test.ipynb#W2sZmlsZQ%3D%3D?line=11'>12</a> return response.json()
#
# File ~\AppData\Roaming\Python\Python38\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\AppData\Roaming\Python\Python38\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\AppData\Roaming\Python\Python38\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\urllib3\connectionpool.py:714, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     711     self._prepare_proxy(conn)
#     713 # Make the request on the httplib connection object.
# --> 714 httplib_response = self._make_request(
#     715     conn,
#     716     method,
#     717     url,
#     718     timeout=timeout_obj,
#     719     body=body,
#     720     headers=headers,
#     721     chunked=chunked,
#     722 )
#     724 # If we're going to release the connection in ``finally:``, then
#     725 # the response doesn't need to know about the connection. Otherwise
#     726 # it will also try to release it and we'll have a double-release
#     727 # mess.
#     728 response_conn = conn if not release_conn else None
#
# File ~\AppData\Roaming\Python\Python38\site-packages\urllib3\connectionpool.py:403, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     401 # Trigger any extra validation we need to do.
#     402 try:
# --> 403     self._validate_conn(conn)
#     404 except (SocketTimeout, BaseSSLError) as e:
#     405     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#     406     self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File ~\AppData\Roaming\Python\Python38\site-packages\urllib3\connectionpool.py:1053, in HTTPSConnectionPool._validate_conn(self, conn)
#    1051 # Force connect early to allow us to validate the connection.
#    1052 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1053     conn.connect()
#    1055 if not conn.is_verified:
#    1056     warnings.warn(
#    1057         (
#    1058             "Unverified HTTPS request is being made to host '%s'. "
#    (...)
#    1063         InsecureRequestWarning,
#    1064     )
#
# File ~\AppData\Roaming\Python\Python38\site-packages\urllib3\connection.py:419, in HTTPSConnection.connect(self)
#     410 if (
#     411     not self.ca_certs
#     412     and not self.ca_cert_dir
#    (...)
#     415     and hasattr(context, "load_default_certs")
#     416 ):
#     417     context.load_default_certs()
# --> 419 self.sock = ssl_wrap_socket(
#     420     sock=conn,
#     421     keyfile=self.key_file,
#     422     certfile=self.cert_file,
#     423     key_password=self.key_password,
#     424     ca_certs=self.ca_certs,
#     425     ca_cert_dir=self.ca_cert_dir,
#     426     ca_cert_data=self.ca_cert_data,
#     427     server_hostname=server_hostname,
#     428     ssl_context=context,
#     429     tls_in_tls=tls_in_tls,
#     430 )
#     432 # If we're using all defaults and the connection
#     433 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     434 # for the host.
#     435 if (
#     436     default_ssl_context
#     437     and self.ssl_version is None
#     438     and hasattr(self.sock, "version")
#     439     and self.sock.version() in {"TLSv1", "TLSv1.1"}
#     440 ):
#
# File ~\AppData\Roaming\Python\Python38\site-packages\urllib3\util\ssl_.py:402, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     400 if ca_certs or ca_cert_dir or ca_cert_data:
#     401     try:
# --> 402         context.load_verify_locations(ca_certs, ca_cert_dir, ca_cert_data)
#     403     except (IOError, OSError) as e:
#     404         raise SSLError(e)
#
# KeyboardInterrupt:

# %%
data
# Out:
# [['common_voice_sw_28581540.mp3', 'eyekihho shna maa mayae'],
#  ['common_voice_sw_28581541.mp3',
#   'bnda a ne i a aishe w  k wana ee nadaa a mnne ayeataiifstta n en'],
#  ['common_voice_sw_28581542.mp3', 'aa ssa a uwa achimi yaaarai'],
#  ['common_voice_sw_28581652.mp3',
#   'hiaaa jdwa  wa nagishi hwna uuskiia thaa n va shaaana nuaonhusuh'],
#  ['common_voice_sw_28581654.mp3', 'nihassmwili naai t okana naa mn waaazo'],
#  ['common_voice_sw_28581656.mp3', 'etciho  u aiaaan'],
#  ['common_voice_sw_28581659.mp3',
#   'aanainiinckinee ia aniikchwa w wa ina w  echsh a  thmniilii mnwa a  aou  wawaza izhheiiki'],
#  ['common_voice_sw_28581660.mp3',
#   'uwa wkaa nziweei w ww wmo wa shsh ijniw awauiimmaa a aa wfuugajiaa aaeyaijaaljchaa a'],
#  ['common_voice_sw_28581805.mp3',
#   'k o lei e inyiko utiine  ol ikei ne tlaadunwwa  wateendyiwa eke'],
#  ['common_voice_sw_28581806.mp3',
#   'kwwahiii wniiiididd a aee a ai wasaikw wndialsa'],
#  ['common_voice_sw_28581807.mp3',
#   'kkkumekuma immai mia mdi diaanoaublni miiuyaao u itiaala hii iiiwa aw woteiiiiitzt manawk'],
#  ['common_voice_sw_28581810.mp3',
#   'twalamaaa aaeeia la iudaiumuweena aa alwwaa wa tamaahaaauiiwikijimichaiei awmkdidaa taa aalali'],
#  ['common_voice_sw_28581812.mp3',
#   'tiuhaaassaaak aiffra aaya  kka aitaiiu aa ateoa dahhaliiaeda aatuow'],
#  ['common_voice_sw_28582296.mp3',
#   'kkuna  iia minuzea ezesha aabiriuwniabegkianaa kk a k  enyanaaaat acieeea ti  haarakaka'],
#  ['common_voice_sw_28582298.mp3', 'maadaizikama kchakula'],
#  ['common_voice_sw_28582299.mp3',
#   'skuutcha gui h ufanmnia uawnma a asizzia wou ukuoiziia auu mnaafa aszamn amnaakakufauorer anah ane'],
#  ['common_voice_sw_28582370.mp3', 'kko waiiw wa w mishimuu mmunhhunachaau la'],
#  ['common_voice_sw_28582372.mp3', 'piii troufautisanana naasaaa ssa'],
#  ['common_voice_sw_28582379.mp3',
#   'h ao wazinmku wata  wana umhuzeaidireiieaakudawawakee'],
#  ['common_voice_sw_28582397.mp3',
#   'pzaaoo iiaaa ukulabeashshadalani tumna hkuu'],
#  ['common_voice_sw_28582399.mp3',
#   'pi yioimekuwa mssisiewateiik no l jiiwaa y to  m yea yahas a  nmmnyeana a ja an  y aanacdkila  aei  na'],
#  ['common_voice_sw_28582400.mp3', 'cieaki nitaanndka'],
#  ['common_voice_sw_28582401.mp3',
#   'u waananennoni i kiicha kirrefnna neteisi niirlfu'],
#  ['common_voice_sw_28582441.mp3', 'kwkawaaidawa ishina'],
#  ['common_voice_sw_28582444.mp3',
#   'neol la katik knye enieaaesaaka tiila bungwwam'],
#  ['common_voice_sw_28582446.mp3',
#   'mnaenm a lianaza kit o hhahkaauchiuomtoanana iyaya wkubwaa'],
#  ['common_voice_sw_28582482.mp3',
#   'kssi ohisi  unao m apaamwr aini aanyinunlnia na otn maadumn wamahaaii'],
#  ['common_voice_sw_28582485.mp3',
#   'kofawtnanaana uwanshh aajio  aadanidaiiilkiidukaa lrasioniitaateoraadiinrakiilaannadaak'],
#  ['common_voice_sw_28582488.mp3',
#   'kto utta m uwiimkiautu hiuina num mw adiiwahaa nrakkakikwhahuumoishia nara wwh i'],
#  ['common_voice_sw_28582507.mp3',
#   'kehaai hivy a ito za  waakeo dumi iy e umuwnileeze ae n'],
#  ['common_voice_sw_28582508.mp3',
#   'aahanayasshimiwo atsa eu uu smwa  ananisaana kanmmw maaiif'],
#  ['common_voice_sw_28582509.mp3',
#   'kaatikaw maume oa no awwa aurid a m aao alio wchini namkannidhtataa lao'],
#  ['common_voice_sw_28582510.mp3',
#   'kalendlaedaoun tegeinee n kiukioa wa haaanagaamui isiianodjanana nw tasaabwa'],
#  ['common_voice_sw_28582542.mp3', 'ena haiil  ita addinnchikawmana mosukawu'],
#  ['common_voice_sw_28582543.mp3',
#   'ia a wseajeimm ojba aanichini yaara  wcsi n'],
#  ['common_voice_sw_28582545.mp3', 'napa tikaa oteunnia a nia'],
#  ['common_voice_sw_28582546.mp3',
#   'kh w waktnjmiwa rna a eza w yyi kuwuoumma  mmaa  mmnanalafwiriku eumiubjaauwa apeeepka watwuiayjiimginia'],
#  ['common_voice_sw_28582547.mp3',
#   'cnchinia wusss leilla kriitiml la otuola yecchu wae hct att  ni'],
#  ['common_voice_sw_28582577.mp3',
#   'iileianzishha  ainana m mkpnen maa a uta aummmmwonjalatieklannan hie ndoo'],
#  ['common_voice_sw_28582578.mp3', 'ku nyingi znaweza rukndane'],
#  ['common_voice_sw_28582579.mp3', 'uila nmdege hasa na awaduutpyya'],
#  ['common_voice_sw_28582580.mp3',
#   'ka muutillaeiz  iiiiika mwwu ja ket ilvhvyaaz viyahalakatii jaza mna zaamakaza'],
#  ['common_voice_sw_28582581.mp3',
#   'kiy ni mdiwa me w duawud e kihiuv cechia ailetikchauwaki ko chaanarov'],
#  ['common_voice_sw_28582600.mp3',
#   'jina l ihii nd aa iilieakuuzalali wa m ljeatalal chiui'],
#  ['common_voice_sw_28582602.mp3',
#   'taleilzchomnnhuzia a uhaala zzakeikeimia ndaa niaach ma haae'],
#  ['common_voice_sw_28582604.mp3', 'hola wado omatuamwaognaee'],
#  ['common_voice_sw_28582607.mp3',
#   'fii amal  ay y aleantia laastamiwlsi ykenye ealat ana an annmnsiki wakitananii alya n'],
#  ['common_voice_sw_28582609.mp3', 'atcuu ninaarsaana'],
#  ['common_voice_sw_28582728.mp3', 'innachia  wmm njaawatifna umaja uilayay'],
#  ['common_voice_sw_28582733.mp3', 'eucheezakam kig  waoemsha mbulia yajii'],
#  ['common_voice_sw_28582735.mp3',
#   'wakcalamu wa nenotoeumyeen cho  ana icchara oleeza  lio'],
#  ['common_voice_sw_28582797.mp3',
#   'iukkti a aa kazini nash atrikii aaat yakamkhi a wtikjijuo w'],
#  ['common_voice_sw_28582799.mp3',
#   'siil l a tnlicalaticatt anistatl  ahnktiiiik'],
#  ['common_voice_sw_28582810.mp3', 'ouok aniju na mbjia mmekse'],
#  ['common_voice_sw_28582812.mp3',
#   'eizio teyii isii he  enye ny sthaaeni eo  lakimwinisitw p mona atiwa palnmnewamu w ngglaa no'],
#  ['common_voice_sw_28582865.mp3',
#   'ainenamna a ae na kiyna chaubahali uo uthia naisaa na kt kon mwan aji hadienii nne'],
#  ['common_voice_sw_28582867.mp3',
#   'w amfaa awaaoinizetkana ukungizwaurefuw w a way na n mfwuuriaona enee'],
#  ['common_voice_sw_28582868.mp3',
#   'urrut wakisu wavyetii udiuwwajaamondaneromajakuwwviti'],
#  ['common_voice_sw_28582870.mp3',
#   's wataubagu uufsannaananaa w  wilddio ukaaeuonilenine  wanachananne wekatiln aaaaan'],
#  ['common_voice_sw_28582948.mp3',
#   'ima ajiiiaazii ka a naenyikaalyanaakn andii amt owa wna at maabahaahakianii'],
#  ['common_voice_sw_28582949.mp3',
#   'tu uniimmwadjakaihaauhusikbwwakabikatiuahurliioh'],
#  ['common_voice_sw_28582950.mp3',
#   'auuka  enaichin  wanawanatikat oliki na utooothhi kathnia wataaka ati'],
#  ['common_voice_sw_28582952.mp3', 'ranis aka ni nyruananyeusi'],
#  ['common_voice_sw_28582993.mp3',
#   'pnnhaishhammti awaiidaakawakati owo hyli kowana gmu una ouii'],
#  ['common_voice_sw_28582995.mp3',
#   'tai yidegekrha sa ama aangei e sonantwa mtili'],
#  ['common_voice_sw_28582996.mp3',
#   'u abu ayana kieye ay hhajjiemu haham mnuiulnmusht aiakka ailii koaanujieashssh lawa uaa miyyaaasarasuo wkammaalashuir i'],
#  ['common_voice_sw_28582997.mp3',
#   'pia yileanin chmcheaizua vavutchgakga ne tchia iralkitawk oarawkztiingmi'],
#  ['common_voice_sw_28583091.mp3',
#   'menyea siile yasilr aaallshi huo kammmm aonaki aare'],
#  ['common_voice_sw_28583095.mp3', 'imat anchchi yakk alliawana'],
#  ['common_voice_sw_28583098.mp3', 'enyeji ni hatwa wakaamila llaakiuy'],
#  ['common_voice_sw_28583151.mp3',
#   'itaanguka e anaish nw waaawkaet likiena waluuheyriiikannwaniaa atft mhhe adii mn'],
#  ['common_voice_sw_28583152.mp3',
#   'bjoldan  luounubawwa ko ussko ammkursheirii athan'],
#  ['common_voice_sw_28583153.mp3',
#   'anasea woamawaii fia y achikawa esa ninu muma a jegmw ula kibwa niniuni'],
#  ['common_voice_sw_28583197.mp3',
#   'na atoalnion  anctii mi l teenhnisalanianat'],
#  ['common_voice_sw_28583204.mp3',
#   'eenine e jee   ni ln tu ni yi y aw tihaduhuvya na mndiia haana lukana n na l neeldi'],
#  ['common_voice_sw_28583275.mp3',
#   'fkshndakisidin iyaakil ma akama waruhushha'],
#  ['common_voice_sw_28583276.mp3',
#   'lukha a zackidub a ut nt ti naata dia mbalim aelnesza ai mgmai jan'],
#  ['common_voice_sw_28583277.mp3',
#   'dmagaananana  at egk atika waakuu lie hwatammaauee alu wami'],
#  ['common_voice_sw_28583278.mp3', 'lieonoaicacha na walwaubaaa kii'],
#  ['common_voice_sw_28583279.mp3', 'uw aohu weza kko amawdafuuoo iillam'],
#  ['common_voice_sw_28583338.mp3', 'ikaaszivjilo wacha vijawailiamvina'],
#  ['common_voice_sw_28583340.mp3',
#   'haddjune kra n mnene urnsoriaayao  ilaattankaraa awoanaichin a ammawataatif'],
#  ['common_voice_sw_28583342.mp3',
#   'i  muuunee uhurtu miarana andlizmsieatik kasa naaa ahakea upigajiikpicha'],
#  ['common_voice_sw_28583344.mp3', 'aliyew ecuchezatintefca malechia'],
#  ['common_voice_sw_28583369.mp3',
#   'nchis nist anyyingi htu mmi natnalnak mekiehtkaamssinimmwaw sa'],
#  ['common_voice_sw_28583370.mp3',
#   'tuainenza k inidbdgjsaijio aw w trot k ia atrnishen'],
#  ['common_voice_sw_28583371.mp3', 'nyao nza ni ndeffu'],
#  ['common_voice_sw_28583411.mp3',
#   'kkaieliiaazauhishrik a tiecamashnga mna auim nawucsaanwama kia wamt ao'],
#  ['common_voice_sw_28583418.mp3',
#   'waaeno walieenzisshawashaa ma a mio wanaueta waoum a oao ok balalaairikaa'],
#  ['common_voice_sw_28583420.mp3',
#   'haie amach ie ankit dyininchi  aeki anhajjuudic aano nkha'],
#  ['common_voice_sw_28583423.mp3', 'wafwa timm uhmunielo'],
#  ['common_voice_sw_28583460.mp3',
#   'ka attiya unusu keonvulnna mnennoenmyennulumpaasicaaa ela n'],
#  ['common_voice_sw_28583461.mp3', 'manen uffaywoa nn asiylbi'],
#  ['common_voice_sw_28583462.mp3',
#   'tienik katektkam ochchi wa mw t wa mmaawozur eat mna wteei'],
#  ['common_voice_sw_28583463.mp3',
#   'akila  lu ghauawanana  mnenanopaw taun jinensia awaaddika amwaneno'],
#  ['common_voice_sw_28583464.mp3', 'wliolaeuchezaatika ngielaenznzaniaa'],
#  ['common_voice_sw_28583504.mp3',
#   'a dobadiilk oatiao aiteendaadmji wak ladili uuandeeea kuta mulioa a'],
#  ['common_voice_sw_28583507.mp3',
#   'raltiykkchis za tcinnmlataeiakka yargeniian naai'],
#  ['common_voice_sw_28583511.mp3',
#   'ktaahuokaranichimi a wanaawkaco wriidkna waadoksiikama  maatfu maidiimi'],
#  ['common_voice_sw_28583564.mp3', 'aliriiaku wanaawtiotoliiw'],
#  ['common_voice_sw_28583565.mp3', 'baaada akiforcha atea ka inoilaldofwoeo'],
#  ['common_voice_sw_28583567.mp3',
#   'odetkreiam huuhung uk na  jiadhuhmmnaaen a awaosssdo  are yad dindi y a r husiengresanawaufolraansa'],
#  ['common_voice_sw_28583583.mp3', 'mnmji ko nn muniiukaa'],
#  ['common_voice_sw_28583584.mp3',
#   'kjeendnrileisa ak wanz aza iloabawhadaasi n uoduoufwa ta whuruuukwauualansia'],
#  ['common_voice_sw_28583585.mp3',
#   'katkatiais o autokiaatila tuf uawatiika stfiholei a tsilaniii'],
#  ['common_voice_sw_28583586.mp3', 'kuuoca wanz chegecha lwa macha ovs'],
#  ['common_voice_sw_28583587.mp3',
#   'kaeliuciliahilsabhadichi ha ais in na afiihi haya a leniewa wa wimiwe e'],
#  ['common_voice_sw_28583639.mp3',
#   'imajika  aonama dawwnaekie anamiukeimnena adumaaw ni nnme'],
#  ['common_voice_sw_28583641.mp3', 'kkkabla yawurjiluann  ela biya ualaaay'],
#  ['common_voice_sw_28583643.mp3',
#   'kccichaabu tcheijjin  ala   ka apatian analatankilya aiani cokkatikaa knn ol aaka e'],
#  ['common_voice_sw_28583674.mp3',
#   'lugha meeikairibia a to  ia kashahi rarabuunidili'],
#  ['common_voice_sw_28583675.mp3',
#   'dddta ea adbaardu oaa hatu mmchhiii ktcuui tukiieau heidiy  n'],
#  ['common_voice_sw_28583677.mp3', 'kujpaandre a  agharribi ni maai watsi'],
#  ['common_voice_sw_28583680.mp3',
#   'kaaiikcshuau ma uustiwau utwa a muhiikihnawjihiushcch emnnaju k mu kah i nakidnam anan a ma  ahari'],
#  ['common_voice_sw_28583681.mp3',
#   'al ikuwa n n n enaldolukatidkeita ii ksaiwwi'],
#  ['common_voice_sw_28583732.mp3',
#   'ih liyo ala yansisha ammidkii y a iwananza  abaadellil'],
#  ['common_voice_sw_28583734.mp3', 'naatedei me aka akl aadaatbla nchhii'],
#  ['common_voice_sw_28583736.mp3',
#   'taaggza maanidnb haalahii njia u za mmwaniziimia naikianatahifua'],
#  ['common_voice_sw_28584065.mp3',
#   'zz ahidrithirrtzinn honziinanaz churika tianaa k hadriaa nch an nan khdrinyi ku u'],
#  ['common_voice_sw_28584066.mp3',
#   'i ni nkb uuliiko  wagaanininmuginneds ta umuiloa ana daa mu'],
#  ['common_voice_sw_28584079.mp3',
#   'rikanashaiien tha l leskee aizamnatesuienaw wwaaa udwawaaawana'],
#  ['common_voice_sw_28584083.mp3', 'ma naayke ni nmaha uawaa kuaano'],
#  ['common_voice_sw_28584086.mp3', 'kuwasasemukw ste mnakaa keleki ya mu'],
#  ['common_voice_sw_28584114.mp3',
#   'kw kuaw hga  diullkaaee  ejene kusls aa a a ekaea ya e eischijit en n na ma a il ja nmlaa nna'],
#  ['common_voice_sw_28584116.mp3',
#   'iekaienza kuhia kiwa ana mrmrlilwaamiyakahsiiamma h'],
#  ['common_voice_sw_28584122.mp3', 'uuta wala mm z i namwen wa mta'],
#  ['common_voice_sw_28584140.mp3',
#   'siimji mikubwa wakabwihta kiti a ni aeiti wa bima'],
#  ['common_voice_sw_28584145.mp3', 'iufbjuia hosaaw ba hharae'],
#  ['common_voice_sw_28584149.mp3', 'yeeenia asleaote'],
#  ['common_voice_sw_28584153.mp3',
#   'kwnneenggsi yaki ataif   nwmaechindawamwa amnaanni e aaasciana'],
#  ['common_voice_sw_28584159.mp3', 'kileno ni i a mwwanwaukchuoumi'],
#  ['common_voice_sw_28584171.mp3',
#   'ikhaleita yaik phoatestamti a   h  aukpia l kintnk itikt latl ya teitla'],
#  ['common_voice_sw_28584172.mp3',
#   'fhalafumuu ni mpgachieaaa ngo lana nambmdio'],
#  ['common_voice_sw_28584175.mp3', 'n ni ciar ba naceaa ncchhi'],
#  ['common_voice_sw_28584179.mp3',
#   'chabaa ayakeikwiliuwa uwa gnwaazauoezo oamchhi'],
#  ['common_voice_sw_28584183.mp3', 'feni mtalam kaikkmkatikkkamsakamnkararee'],
#  ['common_voice_sw_28584197.mp3', 'ia aeni y raffiiki waowengi'],
#  ['common_voice_sw_28584217.mp3',
#   'fdrmeiorla  ffoaaddieede aa do guad uea djinla o glsmcciidiaa'],
#  ['common_voice_sw_28584222.mp3',
#   'ihhaa kanno hiilikwwadbjaa hahubwa ariakiishiwo w afilka kazi azzili'],
#  ['common_voice_sw_28584223.mp3',
#   'alr buatika oanna mmeaaardiiimarbarndidnbaa adlo ne aana na'],
#  ['common_voice_sw_28584245.mp3',
#   'itfpia iliia auandishw wa avkta ddi vyw lasia ksiwali'],
#  ['common_voice_sw_28584248.mp3', 'ia ya l n n e entinenaaiaaltoannnnai'],
#  ['common_voice_sw_28584250.mp3', 'a marachninsariola ji mlde ldta'],
#  ['common_voice_sw_28584256.mp3', 'haauna  abaaiaalisa ma waaail'],
#  ['common_voice_sw_28584262.mp3',
#   'ini at okea aidunia yautate  mnaale y mbu wat wanishha'],
#  ['common_voice_sw_28584263.mp3', 'nji mkko w a mj mu waji o i bsutann'],
#  ['common_voice_sw_28584264.mp3', 'trjeni ekaee na otoomni mmw njatu'],
#  ['common_voice_sw_28584352.mp3', 't aika mneleatalanint yaltliti'],
#  ['common_voice_sw_28584353.mp3', 'assaaishwa hn hua  shaumuwmakrilbalialayi'],
#  ['common_voice_sw_28584356.mp3', 'wati nao tedislcaainisaa wa sataat w mt'],
#  ['common_voice_sw_28584389.mp3',
#   'vi imi avahaa ziiaa ada a viaezktoaea kwwatooebwana wto zina'],
#  ['common_voice_sw_28584392.mp3', 'afsszake kuu zszio jijj ni nda eitanlamm'],
#  ['common_voice_sw_28584394.mp3',
#   'm kbaiziihmti wa a audumuw awarlii an wanaafuunzi'],
#  ['common_voice_sw_28584395.mp3',
#   'sjinia taokeia hasa at k nd lallalakropikiiadunmii af'],
#  ['common_voice_sw_28584410.mp3',
#   'ian waka kakh woolo nilughaharasmniki ha n a amsa'],
#  ['common_voice_sw_28584412.mp3', 'enelaouilila ya a hil kkanlolzzwanya'],
#  ['common_voice_sw_28584413.mp3',
#   'aa yaa   uhwa nargaa naayr kul ildlnmmaraisha maaayia akimler nrani yraai ih'],
#  ['common_voice_sw_28584414.mp3',
#   'kana hamaarakiamirijuwi nihshiaahaak kanakiijana'],
#  ['common_voice_sw_28584415.mp3',
#   'u  hiwa ali wa na hadkawa kilishhaieiverria au uadaazie'],
#  ['common_voice_sw_28584447.mp3',
#   'aala yae kaohuwananaita mttokiiimitu a mllaaa nn'],
#  ['common_voice_sw_28584448.mp3',
#   'k aihy ttnk a a  anyanthlakstannaakajji ike ow anarkaatiiuka kanminj na wa aii'],
#  ['common_voice_sw_28584449.mp3', 'iko kanle a ayazi wa nichidaa'],
#  ['common_voice_sw_28584450.mp3',
#   'jirkuwa a nchi kujithjienea da ne moo ukalna a nado lathak atif lakroam o'],
#  ['common_voice_sw_28584451.mp3',
#   'luha irii kug ha hri husaa n a lugh azaiiha z walabuae'],
#  ['common_voice_sw_28584472.mp3',
#   'm packanaa n a aman mnistarubuia na dbahaaadrinniic'],
#  ['common_voice_sw_28584473.mp3', 'na a ena nyingi wope'],
#  ['common_voice_sw_28584474.mp3',
#   'ih i hvyo taa  la mmji wa janme  ikawats ya eayaji alla ji dakaa'],
#  ['common_voice_sw_28584475.mp3',
#   'imepapkana a ufuirikaa k sinina mstu unkdijiji'],
#  ['common_voice_sw_28584476.mp3',
#   'i aw uhaeanaishimiw wana wokwatikamwatakaatiu'],
#  ['common_voice_sw_28584502.mp3', 'uia no mengi nngi e nee'],
#  ['common_voice_sw_28584504.mp3',
#   'd a mniii a jineane il olienaewauoaawautek aeti chiuna cchi'],
#  ['common_voice_sw_28584505.mp3',
#   'il o hiiin k cavchaabshaa uumnw n thi loliji  ca abrazilili en'],
#  ['common_voice_sw_28584509.mp3',
#   'jibu  lakiinliukw wan aajisha wala ujzvohami aiounmkigerrelza'],
#  ['common_voice_sw_28584527.mp3', 'bnjangzwah w aialiwounj'],
#  ['common_voice_sw_28584529.mp3',
#   'zote bdbililii io i   ti e nama mmlaka y a nt na nje'],
#  ['common_voice_sw_28584531.mp3', 'mahaid t wauchi nam iaitoameio dil'],
#  ['common_voice_sw_28584533.mp3',
#   'wa mna me ne aeilamagweaei yananng yamacho ongne a'],
#  ['common_voice_sw_28584553.mp3', 'hauoo h w jiuuhuz aimmnjmihdhhiiotiii'],
#  ['common_voice_sw_28584554.mp3', 'ard adi ak aioo ngezea harak'],
#  ['common_voice_sw_28584556.mp3',
#   'chowooni kndwa zakiuchmni ugajti a ne aaii do ni ku aoja a chi aajinnadii nina  unvuoi'],
#  ['common_voice_sw_28584557.mp3',
#   'kwnienaaashiamoia wal s a na  wakule enye emyewewvunda a niiaaki'],
#  ['common_voice_sw_28584559.mp3', 'ina kttana a inabraastezii inaahara aria'],
#  ['common_voice_sw_28584579.mp3',
#   'kwatagino alii bdbiila awayhhwkuna haja ugal waji kieen eo'],
#  ['common_voice_sw_28584580.mp3', 'baoa teengenezwanamti wkatu aw'],
#  ['common_voice_sw_28584581.mp3',
#   'ana eisaawkusha uuliwa naguueinna rais wukwmatsaaupekeee'],
#  ['common_voice_sw_28584585.mp3',
#   'kili nyadga au  wana ta abi an akchiik okina hpa ta emmisiu uiliiliga ago'],
#  ['common_voice_sw_28584587.mp3', 'kopande la zividea ya hingoo'],
#  ['common_voice_sw_28584607.mp3',
#   'maizsiwavadha wauu wanaviowawvya juv z yaidi'],
#  ['common_voice_sw_28584608.mp3',
#   'maaene eakealiekwa s mneooel ayayamap ana a'],
#  ['common_voice_sw_28584609.mp3', 'alifpfuatta aoorzeie urtikaarda'],
#  ['common_voice_sw_28584610.mp3', 'ni mneza eekeleipata wuaa'],
#  ['common_voice_sw_28584612.mp3',
#   'kwn ne eezi arastmgiimjui inannaa rangi lih tizi'],
#  ['common_voice_sw_28584632.mp3',
#   'w otu wachaichawa wnaeissawwannchwa wapilriwanaannissza chalela nadaawaszawhuhiwaai'],
#  ['common_voice_sw_28584633.mp3', 'ia anoraei oiimgi ereiza'],
#  ['common_voice_sw_28584634.mp3', 'anaajuulica  kutrilee hac za wmnaaac'],
#  ['common_voice_sw_28584635.mp3',
#   'mm ass raiwezawkl iamaseialibilia arduummguwa a kiuba adisha raista g'],
#  ['common_voice_sw_28584658.mp3',
#   'wote nieoo wanakatwoe ki raaa uswiihthiihka udhahariiowah'],
#  ['common_voice_sw_28584661.mp3',
#   'awahanna awathasi amiidatakiidiw a w w inatadha ah tu vii wau heim  zaikii'],
#  ['common_voice_sw_28584663.mp3',
#   'a a innelmaalinberiiz mppuuaurfte vi urrto fwi'],
#  ['common_voice_sw_28584665.mp3',
#   'uwanja ho wunan eenea ubw wambwali laljilfuni ini wa'],
#  ['common_voice_sw_28584666.mp3', 'fni ndeeeaunchi ljerumani'],
#  ['common_voice_sw_28584676.mp3',
#   'mwa liofuwatanichu  wafasinnekeatiaca shindea na d ni i wvnia aduniiaa'],
#  ['common_voice_sw_28584678.mp3',
#   'ita llaiibusiita wawaoksena wa odaksh wamaia rikni k aw o tittna tittoliul'],
#  ['common_voice_sw_28584680.mp3',
#   'uwezwouhwokaalammakkenesa bgouneswa gfu getailelatini'],
#  ['common_voice_sw_28584682.mp3',
#   'wkati wa wavia witi la warechu wa wmenyewwew uuaazindwadeehii'],
#  ['common_voice_sw_28584683.mp3',
#   'a t kiaa  arralnnmiidiayaitukatika waldykenye miiti aai b'],
#  ['common_voice_sw_28584700.mp3',
#   'ckatialogazzza  wih iiendizi nieoaci manj omegi n lgha ailiu'],
#  ['common_voice_sw_28584702.mp3',
#   'aa niha wa chamma  aw   mwoja manataehelfu'],
#  ['common_voice_sw_28584704.mp3',
#   'uha iabu iyo ya maaneie mu au aaja u mrimughtbnlhadi ninnafu hasaaf'],
#  ['common_voice_sw_28584706.mp3', 'bladehiaa nchiicaw o vyoavy'],
#  ['common_voice_sw_28584718.mp3', 'tazaaenaa  aiiizioba ado'],
#  ['common_voice_sw_28584721.mp3',
#   'hthann  iese n nnnensteawathilriinttsana utawall  wbaddayiana rtania'],
#  ['common_voice_sw_28584723.mp3',
#   'wasasza ninjchidhaaiulakieninaa za ouidbje nwuky kaamahrikisho'],
#  ['common_voice_sw_28584731.mp3',
#   'mstickiafidiwo uhiwo awol wanaama kta aa oaja wiiz wahijijji'],
#  ['common_voice_sw_28584754.mp3', 'uoka haa mt mieo n neiyahadinicer'],
#  ['common_voice_sw_28584755.mp3',
#   'ed nel alak  tastele iil midwal neniga tssernagol  na ga myaa'],
#  ['common_voice_sw_28584757.mp3',
#   'kltik ma  a ka n nzza akiteataei aoieor ummaaneaneteale li  wamujjiu ini'],
#  ['common_voice_sw_28584760.mp3',
#   'ikaa neugolat ennesam ma gla  leiatil lilaya a na yatlatun yaa ni ck'],
#  ['common_voice_sw_28584762.mp3', 'usi nachaa nea na mouda  nusu mwaka'],
#  ['common_voice_sw_28584794.mp3',
#   'iw aub waunea waatajku bbaaiuii wanamahchaariwlaiilije waakakthiiu w'],
#  ['common_voice_sw_28584795.mp3',
#   'ldeliaa hiydnienll nuina nwa nyao wandiatica at jaangwa'],
#  ['common_voice_sw_28584796.mp3',
#   'ad aml djuule jec chi yu laaafffika aevucalntaekt erenieetkamorocalo'],
#  ['common_voice_sw_28584797.mp3', 'nissia wana ssehmakui nentimistamoja i'],
#  ['common_voice_sw_28584798.mp3',
#   'kkubdbaada y atpowalidiuadiukuw w ao razisiiiawm awaluww mkia nawoi awliidli'],
#  ['common_voice_sw_28584825.mp3', 'ksiiwa keenza wkuruadii imwa h'],
#  ['common_voice_sw_28584826.mp3', 'aijulicaaa maa a mnicaaheelcna aflingmgg'],
#  ['common_voice_sw_28584829.mp3',
#   'mito ulio mgwausa na e dbeua wa wwatuu n  mljmhahhadiwjyegkwa wareehel ei'],
#  ['common_voice_sw_28584831.mp3', 'yo acirgraka smimik l rbctuana nchi'],
#  ['common_voice_sw_28584834.mp3',
#   'nikwa i njiiyin ethu oldiauaza ilowaanaoowaazouukahaaraka pko'],
#  ['common_voice_sw_28584863.mp3',
#   'aw khaz waakinem a uuwathnaahayaamaaa ssihieuiywak'],
#  ['common_voice_sw_28584864.mp3',
#   'tndegjge wawwanaaag zaidige dnwkh awana nyeoupe'],
#  ['common_voice_sw_28584865.mp3', 'mhaa nyii gi kumun um ajjichi ni aaai uje'],
#  ['common_voice_sw_28584869.mp3',
#   'hekaadai meidaa a wa aaiamuaj mumataakamma aaniidafu urumahaharidiienafu lru ufini dff uuku satiin'],
#  ['common_voice_sw_28584892.mp3', 'mumo uuunaendeayah ahadieieawa'],
#  ['common_voice_sw_28584893.mp3', 'veme hw  eaibaad a avaasibbaa yna kaneai'],
#  ['common_voice_sw_28584895.mp3', 'omwishsha waaa'],
#  ['common_voice_sw_28584896.mp3', 'aeda e anaselii dilawnannittw isalaaaa'],
#  ['common_voice_sw_28648712.mp3',
#   'kiwaio kiw bwa cha bwateateista wawcuwakemii nka koiunumawcha koo la kie ganichuana maitaaeciharhia'],
#  ['common_voice_sw_28648713.mp3',
#   'uwaowai kwa awali kuctumlikw  wa ssahaawa kicuwcho ha gulii cajnmncheii'],
#  ['common_voice_sw_28648715.mp3',
#   'anaeshi innyiya ta m liakaa mtaatiif u ufaa yadllmni'],
#  ['common_voice_sw_28648716.mp3', 'kua muda haidaaiil endeile ku'],
#  ['common_voice_sw_28648717.mp3',
#   'iaikouwa rahhiiw wa antaka atlaam ati he usaalamawaamw'],
#  ['common_voice_sw_28648726.mp3',
#   'fffuii yo hieaweza kfka nna na m a  nwuunzhzo yayakialiahashiilaliiauk'],
#  ['common_voice_sw_28648727.mp3',
#   'stfndaiaor riolrwa shiulo ya mana aataeritt'],
#  ['common_voice_sw_28648728.mp3',
#   'hefhatw aawa alir likwa cheezaciwawaka a waiajtyewa wwathmaiat walanitaawatsgwakiwwngoche adca wnn'],
#  ['common_voice_sw_28648729.mp3',
#   'ka atikatiktllotr yaa iiikua na tlatlibmu hhim'],
#  ['common_voice_sw_28648730.mp3',
#   'ewalaki nnyi a aanyigi n nyama  waao  weny nki nei naeilgiaka wanawwol onn'],
#  ['common_voice_sw_28648741.mp3',
#   'imaaiwa aya aaa o u aarefulia yemiinay arantgikahaitiily akkaaa gaikiji lfunma manjayana hahafifu'],
#  ['common_voice_sw_28648757.mp3',
#   'fkeengi ikawae nyea a anaeez kutugmmniwa akw choayahiuouull a h'],
#  ['common_voice_sw_28648758.mp3', 'ak  katiikakatsaniea jaaaenyni'],
#  ['common_voice_sw_28648759.mp3',
#   'dcjoaohneszbiokummuw azizaliua mjhinikeenya'],
#  ['common_voice_sw_28648760.mp3',
#   'kkkuwanisii  i ih  aiaaaaujii huirshaan a a haar za afriaiana hazsh o'],
#  ['common_voice_sw_28648761.mp3',
#   'nittadbauum uhii m ewea kupa da waw haidiyoletouni na nin'],
#  ['common_voice_sw_28648772.mp3', 'hawu indego a wamaenewe wenmy nntin'],
#  ['common_voice_sw_28648773.mp3', 'afffrikaaa ya akuissini'],
#  ['common_voice_sw_28648774.mp3',
#   'iiikuwa sannamukkbwa aabuitsaiduenni  a kab ayila'],
#  ['common_voice_sw_28648775.mp3',
#   'kwa ne a mma ji awpuunywa ni ikaz koat ena'],
#  ['common_voice_sw_28648776.mp3',
#   'u wa hi fu uli a hta wkupa hatakiaiailkchaaa owa ahauumiiie ikisailabgu nikaanisaani'],
#  ['common_voice_sw_28648782.mp3',
#   'hhu nihaanuuii wa uwa nza akiis wahili wdiiea nsimwau'],
#  ['common_voice_sw_28648783.mp3',
#   's araei a dinyeussi neny humduuaa uyuusuyinanjoanuna nsk'],
#  ['common_voice_sw_28648784.mp3',
#   'fwa  idi wajrijardri uukuwimnki  a oa naowana mmekaa mo u wnyieiiklahato k awambmssoumubiiia akn oisshinmbo'],
#  ['common_voice_sw_28648785.mp3',
#   'ieiennicha aull  kwaana  ll ncheitza akiwa ta atiklatakata fuaulyhiinnii'],
#  ['common_voice_sw_28648786.mp3',
#   'wwrenza uut wafsirdriivtabub hfvoa waigiivikimbw kuendeewreizaliim ueaawa ki asminiwhlihaak'],
#  ['common_voice_sw_28649071.mp3',
#   'muf hka na alkakchiusiiadi i ikwa chamunueri akidammakao chaakiajiatumwa niaha'],
#  ['common_voice_sw_28649072.mp3',
#   'tkhaiendiiw a uhshaiiridna hadiirz akikwa gkizo iiuinm'],
#  ['common_voice_sw_28649073.mp3',
#   'uwwaaouuw a kaw y waliiitumh eaedi emwa iawawaim a a ajin holaoatik a seihimummuhihishenk'],
#  ['common_voice_sw_28649074.mp3',
#   'imatiahatofu uitta p ataatitatkaa  uka anaaatoit'],
#  ['common_voice_sw_28649075.mp3',
#   'detetu hiio a nw naika anahkaatia wotwstfiiiikw wuaaunno  h'],
#  ['common_voice_sw_28649082.mp3', 'daa aeeenea gnmgamchaalaaa'],
#  ['common_voice_sw_28649083.mp3',
#   'ii mankarona j m a ajuikaaatiiaa  frikaayoiai'],
#  ['common_voice_sw_28649084.mp3',
#   'uv iie yylreumai wa mwjia na mmulii kiowo tannmniiia kwamdiwa'],
#  ['common_voice_sw_28649086.mp3',
#   'uffwtba uhiiahuucuwamiw hszalishchasumuwauulnyein uku'],
#  ['common_voice_sw_28649105.mp3',
#   'fawi aniza akawei ake hukb asaelioona  akichdia hwas aktikiy hihiiahiizhahrak a'],
#  ['common_voice_sw_28649106.mp3',
#   'faaasa ni iukiioa uvukch a utawarlii a wrnyw ekanyan'],
#  ['common_voice_sw_28649107.mp3',
#   'hea nchiii uemki awelza aa amaye anaaceetza k atikaaaufwazieadikiu a kkuchwo waitu'],
#  ['common_voice_sw_28649108.mp3',
#   'auehednaa aat iien wfaainmew waanawaao   wa a aatkristo  kwuakilhaer ttt'],
#  ['common_voice_sw_28649109.mp3',
#   'hkaratikha y lubrha mga aimaalraza aga y a rastiuii i nna a gjeina a a mweezi'],
#  ['common_voice_sw_28660554.mp3',
#   'ntiko o aapti t aienbal a mk msiniiahh rkiiia dttlalanmnkchi'],
#  ['common_voice_sw_28660555.mp3',
#   'j jbaa ndaae  koa nadiiijdwaw ugjich jiashshanaa mche i'],
#  ['common_voice_sw_28660556.mp3',
#   'dema na a  upatikan na je wa keea wk t newngie dea naku w w udiibwouuhnmnmgkea ssiiie'],
#  ['common_voice_sw_28660557.mp3',
#   'jaio nsiitsu owa nussu   uukyha ikia noiikchui'],
#  ['common_voice_sw_28660558.mp3',
#   'anmguzaaaa aaa eleeamaaiejiimiiwwna bna dah mbdknazea'],
#  ['common_voice_sw_28660672.mp3',
#   'il aiiiaa aiaikaua kij gawumnna gei waliwa achwana wabaadaai'],
#  ['common_voice_sw_28660673.mp3',
#   'piawa al a  iuwawzinmma w kca  a kiuiinirutumachabaaaiija mgurinnayefuw ka chiiaigzaki'],
#  ['common_voice_sw_28660674.mp3',
#   'ihaliwaiu waziiwahayalnkaziunamahlleuiyevljaan lzaayuliiiniid a auhhalikhdk'],
#  ['common_voice_sw_28660675.mp3',
#   'igiioro nchenh sgannhia a nijtiinu  ya ttehfaaayamtjiaiti n'],
#  ['common_voice_sw_28660676.mp3', 'aaahilyo khiatka nayeama  hawemwanaaki'],
#  ['common_voice_sw_28660697.mp3',
#   'khiizio mzizi wa hasiiil ninza m a uw ka naakieniihaiiees'],
#  ['common_voice_sw_28660698.mp3', 'mji uuu ni mnarfuukoa ci mdaji w uhaabu'],
#  ['common_voice_sw_28660699.mp3',
#   'ihiiajjm iinaktaeibaatkie stsirri ka ibumena a mahhkaamma ui ngaanamaawaani w ambadaadrak t'],
#  ['common_voice_sw_28660701.mp3',
#   'innanza n a  wojauwa mwuumo uigamnni  jabamaalilinn aai'],
#  ['common_voice_sw_28660707.mp3',
#   'ganmaao mwehiny yafgfaaya kiha kaazi nmau hkayaha ailubghay a mwiilni nahgh a ishaara'],
#  ['common_voice_sw_28660708.mp3',
#   'jiliuiahikia atia uly aaaadalsiksemlaakiwa alan zanikignkegrearea'],
#  ['common_voice_sw_28660709.mp3',
#   'onandeshiauwemyslla wailieieieetdza nusup eki li jna a bumwyatp iulooni'],
#  ['common_voice_sw_28660710.mp3',
#   'ajiboualiialiia mjini mna maza djzmdwalla gozzi'],
#  ['common_voice_sw_28660711.mp3',
#   'mma ddrialiaanmi n dilriyiaki e mgshoo aalioo wananuuguuza k'],
#  ['common_voice_sw_28660717.mp3',
#   'usi nd aie mti iddowoala unaaresa  tughuza hat aatikuazaaii yannudus'],
#  ['common_voice_sw_28660718.mp3',
#   'uimbwa ulialolilewkuna ktaaeindmojjaa izwa keii'],
#  ['common_voice_sw_28660719.mp3',
#   'iizzo iiinum i o m eotuhiakweta saaabudaawweny naasisi liaean'],
#  ['common_voice_sw_28660720.mp3', 'fu  ia  uitla mua me wwde meeen'],
#  ['common_voice_sw_28660721.mp3',
#   'uizwa hiisdwo zhili wa karatia two w kaabishaaakabaa lahafui'],
#  ['common_voice_sw_28660727.mp3',
#   'natkini atca nchi  emedanm  rlasiiaa haldiukn anma wafau wasu wach atcheiuwaiiandi iio'],
#  ['common_voice_sw_28660728.mp3', 'amoja na kaminy divetst'],
#  ['common_voice_sw_28660729.mp3',
#   'aliwahikucheriati imi wa ta hifay i histanea'],
#  ['common_voice_sw_28660730.mp3',
#   'sanaahiini nnzudrisiananaina drand a fuiya ia'],
#  ['common_voice_sw_28660731.mp3',
#   'hat ariuubwa az haiina unakaa n ow kahjhijiana at  whajndjzeaaiike'],
#  ['common_voice_sw_28660737.mp3', 'kamusi naatian hapia mta aandaauuni'],
#  ['common_voice_sw_28660738.mp3', 'idia nshw lanaawa rnoba'],
#  ['common_voice_sw_28660739.mp3', 'aar za nha aaenichchthenna asi za a'],
#  ['common_voice_sw_28660740.mp3',
#   'jn hhfanya uduuneatiilaci weajnyem a wanynbaa  wahio nza n annoishihfurish a'],
#  ['common_voice_sw_28660747.mp3', 'miibu sarasmi mngnl jaraweenjhi annge ie'],
#  ['common_voice_sw_28660748.mp3',
#   'knmlnaezau kfuahanyanna aaaa n na whtooeggijiekaiibaliichu hak hau abbinnga eheiicho'],
#  ['common_voice_sw_28660749.mp3',
#   'taamu yal ya anashna a nawta heoidrikie na aoaeinienewoaka ama amakaatieiff'],
#  ['common_voice_sw_28660750.mp3',
#   'h alinaatig im yaanackatbyan nchiinaatlatkti b wa a wak ii ha si'],
#  ['common_voice_sw_28660751.mp3', 'kudimmeena akia nnglocha keiuio nhgsudii'],
#  ['common_voice_sw_28660772.mp3',
#   'tnla iy mgbw mtao wyenych a knwada tu llaknmi nkwena ieanyuem mb a zyenye viimba  mmaamnmiea'],
#  ['common_voice_sw_28660773.mp3',
#   'iiiriririirca ishetiaikata ata at etta at hwa  ot taentnefvishtanicshinni naia'],
#  ['common_voice_sw_28660774.mp3',
#   'awaezao maniha aamtawa l mciii mnyuu aa uijanakmt oo'],
#  ['common_voice_sw_28660775.mp3', 'unukamda wa jottoodonniai'],
#  ['common_voice_sw_28660776.mp3', 'iwygiina wa nashiseee mwenyyinie teuniani'],
#  ['common_voice_sw_28660782.mp3',
#   'iiaalli wammjtaalishajinmandajkaiasfihiamu'],
#  ['common_voice_sw_28660783.mp3', 'akaldi waoallawadotida admimrand'],
#  ['common_voice_sw_28660784.mp3', 'motfaouti nikamasinndaan'],
#  ['common_voice_sw_28660785.mp3',
#   'ilei hii wa wkaziwendhikaadaanii waao sshi'],
#  ['common_voice_sw_28660792.mp3',
#   'nszma hh umtyiaa unariishwo pauliso naneao mumgunaeahatia'],
#  ['common_voice_sw_28660793.mp3',
#   'ie alria nyi kcwaanchingi ha eye  ki a ki wduanchagchie a wsioammn'],
#  ['common_voice_sw_28660794.mp3',
#   'ncimaaa ka niumianuan nmbaaaelamkwaeniauc hi'],
#  ['common_voice_sw_28660795.mp3',
#   'imni moja kaia aajinbokuuminana ueja jhagguzi kaaaakaeia yaki ya mbu'],
#  ['common_voice_sw_28660796.mp3', 'aaazi wakeeni wachnmgaa'],
#  ['common_voice_sw_28660797.mp3', 'makao mawia yalnrikuwa mmnyjid ninyyeeras'],
#  ['common_voice_sw_28660798.mp3',
#   'iiwa uaantd wa usteni nmasha lii a kixthi wachaos lla uaesi'],
#  ['common_voice_sw_28660799.mp3', 'kuona ai nambarimbail'],
#  ['common_voice_sw_28660800.mp3',
#   'ahitga ali a gihthia ednlalagha uwal harufu'],
#  ['common_voice_sw_28660801.mp3', 'iihaei hi hudi yashuili ya msie  neo ihuo'],
#  ['common_voice_sw_28660808.mp3', 'mami nne nyyi mwen tu'],
#  ['common_voice_sw_28660809.mp3',
#   'asa  ilheininha kwa amheniza i aniiimaa yaffeeie za ba harhi'],
#  ['common_voice_sw_28660810.mp3',
#   'zsza hadiiu uaatikaaa  wa rangdaan dnmdaahaaraza kiiijaaniinirnana umu unnyei siii na nnaamnzannyie un'],
#  ['common_voice_sw_28660811.mp3', 'jandanz juuna afa nna varzi'],
#  ['common_voice_sw_28660812.mp3',
#   'aai diena utaradjiri wau ur aiearayh ua tok amiriemnaribaanooni i'],
#  ['common_voice_sw_28660837.mp3',
#   'tnaanei zakeeaabezimeaaenkc agjeigi utl knana aakegba kbwa za ma  t roo'],
#  ['common_voice_sw_28660839.mp3', 'nomba msaaata'],
#  ['common_voice_sw_28660841.mp3',
#   'duugara rasmminaya kawaeidnea ni ss a naamzia'],
#  ['common_voice_sw_28660842.mp3',
#   'aal ata ia nafuaastiaksu  ameenti ka yataa m uab shu hurliia ardaeuaandoi'],
#  ['common_voice_sw_28660864.mp3', 'inas ema ean na lizaliwa orowmaa jia alii'],
#  ['common_voice_sw_28660865.mp3',
#   'aieis yaliliwanchinivifu wanana waai azasamwkyansa'],
#  ['common_voice_sw_28660866.mp3',
#   'iiw anadjih hawa walii wamwaba  annawaahawenigge  arazawaksi unnyae khwalaanzasha ha w'],
#  ['common_voice_sw_28660867.mp3',
#   'deo rera ecedaliick ini a adaanc yae nth ya adbwnaalahneni dhiie'],
#  ['common_voice_sw_28660868.mp3',
#   'spishiennteni huuthumeka l acsinarna w arnth aa dao ndegernmmwic'],
#  ['common_voice_sw_28660874.mp3',
#   'admno wakiijikjijhih aafiia alanyim di huwa maz uwa naihalazamazee w'],
#  ['common_voice_sw_28660875.mp3', 'ma ii neo weneadeza laldishino wwakiithi'],
#  ['common_voice_sw_28660876.mp3',
#   'hawaaamnithed  arisa lea mdeaalna zauniy a'],
#  ['common_voice_sw_28660877.mp3',
#   'a a tiwaak eiilis aabuw kaatiya maa ajiaabu hindumn ac sa aa'],
#  ['common_voice_sw_28660878.mp3',
#   'iiuffahamu  ussikililda mti   at uaaamuf kuskiedziaarledilyohadritinai adhaia i'],
#  ['common_voice_sw_28660879.mp3',
#   'nimeam niiia aaia wandii kuwmmo  u waatana usshildija mfwaulaadi'],
#  ['common_voice_sw_28660880.mp3', 'adyidmndooakrmnac at ea mlila ngemit'],
#  ['common_voice_sw_28660881.mp3',
#   'iahhisfhwu maakil sik adi uhsikwaa a khahhameaoenabiik'],
#  ['common_voice_sw_28660882.mp3',
#   'sia an aeziuwanza mw izbmei ah habi  ukw loaia auwna jih nnaahrieaadshwiiibrow r'],
#  ['common_voice_sw_28660883.mp3', 'taariishahiyorhineza kwaaminihaul a'],
#  ['common_voice_sw_28660884.mp3',
#   'dyenchi aduormdl i e io nd a  v nayaidcortu'],
#  ['common_voice_sw_28660885.mp3',
#   'siriiiao ni nkchya ia k wamaiaishsanaakaiblamadarimbahali'],
#  ['common_voice_sw_28660886.mp3',
#   'kikula a mahtsoila etea uei ydu neuukihizza'],
#  ['common_voice_sw_28660887.mp3',
#   'kua ahize himuuoeezi ke a  ateaa mwendowwa kwa mmba alizeidi k aaieyaa'],
#  ['common_voice_sw_28660888.mp3',
#   'watwa a wiede hu ata nguunmjwa  uaalamwntu'],
#  ['common_voice_sw_28660894.mp3',
#   'ce  jellfkfans eamiaa tisir  lcnietmltnnen nlaitsla nic amw oa r tlata a'],
#  ['common_voice_sw_28660895.mp3',
#   'ksanggmwa a o uwwa adi khchuwo ckiahalliewongwzajima laammmdaya'],
#  ['common_voice_sw_28660896.mp3', 'h tahiivyo taza ma ata aiihahachi'],
#  ['common_voice_sw_28660897.mp3',
#   'oummwojahu waliwezakushndaammaan  aaweeneyi'],
#  ['common_voice_sw_28660898.mp3',
#   'ufutaeena myantazmnafasee nia ao mmbaaakaii  mna mwe nde a weeikiya'],
#  ['common_voice_sw_28660899.mp3', 'edy amnaseemmmlm aliddredunirn'],
#  ['common_voice_sw_28660900.mp3',
#   'ikumakanya adhaaiiri yae  ieawblio wmnawlneaaezza'],
#  ['common_voice_sw_28660901.mp3',
#   'uo me kanda mredjieenna ucii ni ma tuuruki'],
#  ['common_voice_sw_28660902.mp3',
#   'aana aiggungnann a umoowa  viyana waac a nahiijcho'],
#  ['common_voice_sw_28660914.mp3',
#   'ie mezao ni nmh fuki iozezeaza j kiendkuliazlez uui'],
#  ['common_voice_sw_28660915.mp3',
#   'miia msiimiie abmwaua nlishsha ar tihbaa naaliimi mh atiibuh u'],
#  ['common_voice_sw_28660916.mp3',
#   'ni anauu ya k nnuzzallnnnuwanaeeissia aaikahaslaudaata hafaiagikisfuey h'],
#  ['common_voice_sw_28660917.mp3', 'badhi yanibd lioltiikiiin neza ulmmii ka'],
#  ['common_voice_sw_28660918.mp3',
#   'msi uiahamsishw ama a  jaibio shaan waron abu ubmnouwsn arriiiw ka bzinsibalalr'],
#  ['common_voice_sw_28660924.mp3',
#   'indatl lilmu iyasecamdan tikaatulanmnl nak itoacsiikt a'],
#  ['common_voice_sw_28660926.mp3', 'ihelmaeiyo ahalito ya  mna aaddiiaamnisa'],
#  ['common_voice_sw_28660927.mp3',
#   'ailiia hawwaanaiua ammhayaailiewa ambeyafukuzwanaa y'],
#  ['common_voice_sw_28660928.mp3',
#   'fua lo aumsiea  undendeil k wamwy oka ayat ma oleadyjeloma ani'],
#  ['common_voice_sw_28661601.mp3', 'aiunni itssam akawwaaaissi  wanzzuaza'],
#  ['common_voice_sw_28661602.mp3',
#   'damyiemi itumya aan eenan  mw aka  mfuaaana'],
#  ['common_voice_sw_28661603.mp3',
#   'kkwecoa kaanaana ufukwniaaa kaheo tuchoaduonunja  unajiaja'],
#  ['common_voice_sw_28661604.mp3', 'mjiimua wwuhuu mni wticheti i'],
#  ['common_voice_sw_28661605.mp3',
#   'ualieuaagiinza chunguza muunnnwo waijejini'],
#  ['common_voice_sw_28661611.mp3',
#   'ma kaawaooa hanna ashaoi aoilaaayaaoao mdww a mjii n'],
#  ['common_voice_sw_28661612.mp3',
#   'inengi a idii kwawwbwa chinni uejeadnonaa y'],
#  ['common_voice_sw_28661613.mp3',
#   'lubghaha aeii ya  na  iiiwwen inii aharara ub'],
#  ['common_voice_sw_28661614.mp3', 'aasa wanaisiipa wammojayaiutin'],
#  ['common_voice_sw_28661615.mp3', 'peenie njgia a ya upiga  na vigtua ta'],
#  ['common_voice_sw_28661626.mp3',
#   'akua amnaya ishtiannmia a n  nanis a a eati lothi rkii  kawawa hldoikssiina wwahodlss  wt rsthateiliikta a nn mtaiahntthotlafak'],
#  ['common_voice_sw_28661627.mp3',
#   'ukwa dhau a sa bsbabu mcheuzw a naa suwa hatiaaaih'],
#  ['common_voice_sw_28661628.mp3',
#   'meiiiin toacia nen uaf ra frrifa aamafaaaathhiaa a a kusicsraeia'],
#  ['common_voice_sw_28661629.mp3', 'kjamu himu   nzunukuktmihi tka'],
#  ['common_voice_sw_28661630.mp3',
#   'nikhopichiam  washegan oo w mb awushereikianno wa  kea'],
#  ['common_voice_sw_28661636.mp3',
#   'ki a w h mojay a mitwa inauoufuwaauruhuumviktikkaa fu  ana i aa'],
#  ['common_voice_sw_28661637.mp3', 'ni ie kiha knao o cha kila dotu'],
#  ['common_voice_sw_28661638.mp3',
#   'omeliimu kwa wata outo keik elihakeaa wa mseinm'],
#  ['common_voice_sw_28661639.mp3', 'ptfuona ma ilia amnmengiei y'],
#  ['common_voice_sw_28661640.mp3',
#   'aaia sh  hnj a aui zaa abaa nna aiwaa rebioufanna kwejizie kirbaadi am mwuishirikaabawu kk'],
#  ['common_voice_sw_28661646.mp3',
#   'mffaaassmihihii niharasikwukwa ea ula h aa'],
#  ['common_voice_sw_28661647.mp3',
#   'tubaaaiaa  h hutulniarsia eheifuula auiitu a  zaniiliyea a'],
#  ['common_voice_sw_28661648.mp3',
#   'hua wsaa aaji wauka w eiia huchukua a mdaadati ki hadisa a  akadhaaatkk'],
#  ['common_voice_sw_28661649.mp3',
#   'nanaaanyyiniia hu wa api na chehiialmgwauw ataa chakuuila  auu awag le a huveny ana akii'],
#  ['common_voice_sw_28661650.mp3',
#   'jidnana  ctegaegediec lii nan oma l anlla  la a mmgie anrt  a'],
#  ['common_voice_sw_28661656.mp3',
#   'pkikuataaliaam naua na  adw aeie ayikieiki d eniliuw waya wmaneep'],
#  ['common_voice_sw_28661657.mp3', 'maa ye naa hao a tia akw nna dadassaa'],
#  ['common_voice_sw_28661659.mp3',
#   'pipikieeieuu umdshaik tachu ili hsaaneffu madjawwnahusanyhf w ichookik uicha a aru'],
#  ['common_voice_sw_28661660.mp3',
#   'kkkmbeeii zaa ma waka ati zngii eai zzinaejulka aanaakkama beki edoniaeaa'],
#  ['common_voice_sw_28661671.mp3',
#   'kkk wweoaawawetuwwla a iteni haawa w wa wawakwleitute'],
#  ['common_voice_sw_28661672.mp3',
#   'ttc c sillnaiaircni iaia mn nneic y nirchtea lakchaictiahehii a aau tteka k c'],
#  ['common_voice_sw_28661673.mp3', 'kwakat tsiekueeji m wwnajiwa a pii li i'],
#  ['common_voice_sw_28661674.mp3',
#   'k uorziiniyimgii nziye na awa aurahefu wakujiff umza a uliiko enyingi ei a'],
#  ['common_voice_sw_28661675.mp3', 'choo tkiikoo cha mlinaakk'],
#  ['common_voice_sw_28661681.mp3',
#   'akkptukppfkfkaatwa riia mia  vad vya ahmn ahiita z uka ala a uuv uka unitoala kieinii ltiy kusaafiaiiabahhhariiii'],
#  ['common_voice_sw_28661682.mp3',
#   'kkujviiaehll  eanyima anaa ch m hhaii aofhussiu kuuto ka   waushu'],
#  ['common_voice_sw_28661683.mp3',
#   'keinateaiia aw awaa anaaae w ajanaanmayeliaaezanauanaanaaa ki'],
#  ['common_voice_sw_28661684.mp3',
#   'ikkieodiwwaa a a biiiikw ukawmdwr azi wa ut aniakakkau kglwgaribo mwauktanzantnii'],
#  ['common_voice_sw_28661685.mp3',
#   'adha waaniisis za t mmbilrizsna adieikeita kgmtatkahadiien itia'],
#  ['common_voice_sw_28661691.mp3',
#   'kia  na was maajiwakchakchi icehei nenkeny'],
#  ['common_voice_sw_28661692.mp3', 'ralla tkiennya na  uganda ai kupitia haka'],
#  ['common_voice_sw_28661693.mp3',
#   'eaihiha kiijicha uchahpa m kindaaaz w cwa kan wekir kwaye aiffhfwelejiwahishijkiii'],
#  ['common_voice_sw_28661694.mp3',
#   'iiiy di yarsaeo naa jeiicho nunei ndi  aieil kiaenilla k n neni ndogo'],
#  ['common_voice_sw_28661695.mp3',
#   'upassaa  fuatiia h aana cha aapkaitka amachaa ake'],
#  ['common_voice_sw_28661706.mp3',
#   'keiha ia mualiiiisha taaidizadtahifa laaike'],
#  ['common_voice_sw_28661707.mp3', 'aialicheza ka o mh mbuliyyaajlii'],
#  ['common_voice_sw_28661708.mp3',
#   'i tcaouariya ouauwufti   ili ta ufa  utiaa t nkchi nankccihhaik'],
#  ['common_voice_sw_28661709.mp3', 'fchjiea aliiauo biema  a wa ara zaanziaaf'],
#  ['common_voice_sw_28661710.mp3',
#   'ppiiichwei kiiuupisa  na mn hata ki ni fuwaenyenchaka  ap'],
#  ['common_voice_sw_28661716.mp3',
#   'kikkkuksiinieainai  ugiausinuiuda ameindneza a oa  tlliniikk i'],
#  ['common_voice_sw_28661717.mp3',
#   'kiiaaza   wo wishawawujriuizziwakiawkiiinga k uhaiuri ikachia mnchhenda mn a nmbaliinmbal'],
#  ['common_voice_sw_28661718.mp3', 'iutzaaaafuohuuweza pierpkujenkawmbawaa'],
#  ['common_voice_sw_28661719.mp3',
#   'f n atoikiaka maka fa sa aurriakf arula  aia  anaahalicchhiiaa'],
#  ['common_voice_sw_28661720.mp3',
#   'f ntoiatwa huwasieiaua  hanfmiikaajritu a ijienanla adamanawaariisa w  w oul isi ki'],
#  ['common_voice_sw_28661852.mp3',
#   'elea waa u aaziwengi w aliwa awao watiist   wakamniitak aolliiki'],
#  ['common_voice_sw_28661853.mp3', 'aliuwaaaaiajaliamgtokaa'],
#  ['common_voice_sw_28661854.mp3',
#   'watuhvitui nam  ha allio naezauwe   auouwaanamnaama alimda yyli'],
#  ['common_voice_sw_28661855.mp3', 'aiwa hiuichidainu i aiawaaeya hflin'],
#  ['common_voice_sw_28661856.mp3',
#   'muwa kaw iwa ufawa aa fiik  titvywaw   wa mtuwcfsiu wa kananmchiiihiizajizlanniiyeo aaliejlerihinuchhanauulia a thalatibu mmbhm'],
#  ['common_voice_sw_28661869.mp3', 'z a izibakamasiina ataka naz ibaa'],
#  ['common_voice_sw_28661873.mp3',
#   'iihi iy wa jamw la kawaaaddaa kaikay jainm'],
#  ['common_voice_sw_28661874.mp3', 'mmji   na wakazinitu milli on ni'],
#  ['common_voice_sw_28661875.mp3',
#   'mnimwjawaaoua nnaubu waua ana ainiunnaa a y aa'],
#  ['common_voice_sw_28661876.mp3',
#   'tn akkuishii aiikia nn a  tiaori haa y p wamo dja a wa kiiituma luuga  wa maa rhaiania aademnlm'],
#  ['common_voice_sw_28661892.mp3',
#   'a anu  uhuhunuo waanziischi mnaiimbzb alio aalie aza waalili'],
#  ['common_voice_sw_28661893.mp3',
#   'kaameiuwniili ka uoanila ya jeumaani hadi via kyyakwaanza n aidudniia'],
#  ['common_voice_sw_28661894.mp3',
#   'aarii aha wa ninzika ushi ikildiemwm uvuui'],
#  ['common_voice_sw_28661895.mp3',
#   'knaa m kteene u laa mni mbaa i nhi uuachiithainmniio'],
#  ['common_voice_sw_28661896.mp3', 'kuto aa na na muziii wak kizazikiiia'],
#  ['common_voice_sw_28661927.mp3',
#   'iknr aa hiyi iaag ne  a asiisi maraimba raiynyini naeszarsiria leimna arkidin'],
#  ['common_voice_sw_28661928.mp3',
#   'vyei ua hasa ve aanmnanniy a vye vnasayyinn'],
#  ['common_voice_sw_28661929.mp3',
#   'fimtjihuhuh huuntea   un ilyoiia a u vuathia na iu mkuugu  y iis i ya'],
#  ['common_voice_sw_28661930.mp3',
#   'kuuna mmoamenkgiy yailiytaeaeya waiyoha arannaeei iiiiama a hhayeyafu ata a a'],
#  ['common_voice_sw_28661932.mp3', 'akiwa na a cheocha kwongozabaalozin'],
#  ['common_voice_sw_28661933.mp3',
#   'iiiinmaara nyingi i hutoe keraza io daasaha mu waoja wkwai ui'],
#  ['common_voice_sw_28661934.mp3',
#   'kkna  elaaaamiii mbzaan ni aszini unuj aahnnkaaiaznnngujabaa'],
#  ['common_voice_sw_28661935.mp3', 'aikimnba kaaiwa alaaswakudiujiiuunna mj'],
#  ['common_voice_sw_28661936.mp3',
#   'emi yaaw wkaaisi   wwemgiwann  ai li ewaw a utissana'],
#  ['common_voice_sw_28661942.mp3',
#   'umbaalii u niia ma waker w a a ii  awakkwa adaada aiisaallaa omm'],
#  ['common_voice_sw_28661943.mp3', 'sultaaernial a oubayrliliaear n'],
#  ['common_voice_sw_28661944.mp3',
#   'inima aliwa  wamu eshimmcii ndimunkwoa awa ile m aj yaru  aasie ienena aatania s'],
#  ['common_voice_sw_28661945.mp3',
#   'ki cho chae kina umbwwa a yyyaainna ma chma uw'],
#  ['common_voice_sw_28661946.mp3',
#   'iweny maendea aajidaaninatairira hwaukia waaaabjuu'],
#  ['common_voice_sw_28661947.mp3',
#   'la aini ia wunna ama amuijisia hhk a  alrii amaviyiyan mmwanniya inayayooawsa ksapiisha akikawa'],
#  ['common_voice_sw_28661948.mp3', 'kuna aia meinezza nnbungei'],
#  ['common_voice_sw_28661949.mp3',
#   'siwannabdaamu nnaanyawmaamaliiyawanaaassikioma eiel ki chwa i'],
#  ['common_voice_sw_28661950.mp3',
#   'baadda yaeaalahy mian nafa a n akaansinchi nemaa r ikaaaanie'],
#  ['common_voice_sw_28661951.mp3', 'iio ka atia kiovvkcha ncchi'],
#  ['common_voice_sw_28662012.mp3',
#   'mni moto waastsiita tkaati e wa a tl mna amnkkaica ta mmiliatya yakii'],
#  ['common_voice_sw_28662013.mp3',
#   'ima fvukta a hayamaaziiiaiiiilnmcheyangy nyikw w ake ymi yaliaaalimba ilal'],
#  ['common_voice_sw_28662014.mp3', 'ualamma wa a umla y a ni nnzzri'],
#  ['common_voice_sw_28662015.mp3',
#   'sii lnai mauwahulaa aadurduuka aajya yaniinayajuu vya maaaji'],
#  ['common_voice_sw_28662016.mp3',
#   'jeentiia mmu wa za  mai iza j itika aa ngazaju hh'],
#  ['common_voice_sw_28662022.mp3',
#   'teta  uka ane   na ethn waaa m amwnrt aatitt aww  waakaolii k eaiawaoataodloakthiana wa atdoaksih a wa am astaeerikie'],
#  ['common_voice_sw_28662023.mp3', 'tkmakam ouuiyako  iiamanistip yari na'],
#  ['common_voice_sw_28662025.mp3',
#   'ii vvioo siseheemuhya yeana o  laordi omaja l uila  a'],
#  ['common_voice_sw_28662027.mp3', 'alikuwa haa nachambaalai'],
#  ['common_voice_sw_28662029.mp3', 'tiai nni wa asaant waatlirikitltith'],
#  ['common_voice_sw_28662039.mp3',
#   'ifinetof htiana a kigarday baa audodoambaandlioga n y a iki aohushfro aa ssia  ikeiy ea'],
#  ['common_voice_sw_28662040.mp3',
#   'traniizama nia na ehchien i wa  na waaakatoliiectina wal do xshi k anw  t aailfu im mmthr adtil nmiu'],
#  ['common_voice_sw_28662041.mp3',
#   'llaioa na hastimw nnakaniis a kaaoelriki  hiwarhordloks i na  ala hrdoks uma saitaarikia amao mta akeifu'],
#  ['common_voice_sw_28662042.mp3', 'adliwa binamumu am amedd'],
#  ['common_voice_sw_28662043.mp3',
#   'auda liizsimna ea ujihsha awaumivuna uu muakhu laha ha'],
#  ['common_voice_sw_28662051.mp3',
#   'dbwor iwanna ai rnnawaenikwenyenbahadii yyo  b iy'],
#  ['common_voice_sw_28662052.mp3', 'aovuti rasamni ya mmjii'],
#  ['common_voice_sw_28662053.mp3', 'we yiyni mke a kwanza waa mmzee ik jze eh'],
#  ['common_voice_sw_28662054.mp3',
#   'amicha kakaatwezaidi ka wwkaaioh wuuwinnaahusshsha wakundi azaa'],
#  ['common_voice_sw_28662055.mp3',
#   'baadara uuhnukwwonn unendeleaaapiiiakuamisiindgia nasu ana mmis'],
#  ['common_voice_sw_28662060.mp3',
#   'ma hhaadu rey raawaida a nistrshiwouduwawiyhinyityer ia n ndaa fwa u'],
#  ['common_voice_sw_28662061.mp3',
#   'niiinchii ny wasalamuwengi kul k nyyenginz o i dwnniaanm'],
#  ['common_voice_sw_28662062.mp3',
#   'fiikueny enuusu ya ka wseazinni kunan amwai  meaengi'],
#  ['common_voice_sw_28662063.mp3', 'mcheza jiibu aanachezasasa'],
#  ['common_voice_sw_28662064.mp3',
#   'ivyo mmwawa ani muhimu katiotamaladu n w a wwae'],
#  ['common_voice_sw_28662069.mp3',
#   'karichaama aiaachiwr io icha ajimbwanraim ama  aiw haadigiaakifa ana namaa'],
#  ['common_voice_sw_28662070.mp3', 'kwasaasa imeuwa kaani yataazooiy'],
#  ['common_voice_sw_28662071.mp3', 'una ia  uwanjaa mndolue wa ndedge'],
#  ['common_voice_sw_28662073.mp3',
#   'maartkaarni muji mitaatiiflu w  uitsslaaamm'],
#  ['common_voice_sw_28662074.mp3',
#   'kinnicha adowa a ani itla lelezanjio o a mllaa aci a eneo mfula nt'],
#  ['common_voice_sw_28662077.mp3',
#   'ikuw awdjiumea aw auuwlihfa anya aashi k a akushiirrkianabilila gb buiewanamwaakabaka'],
#  ['common_voice_sw_28662078.mp3', 'imdume lrasshi nyini ana mgkie  mrefsana'],
#  ['common_voice_sw_28662079.mp3', 'numbo lake niakamma bbooma'],
#  ['common_voice_sw_28662080.mp3',
#   'kaamkaariwaw nna haeishimi wna wwakaliliiiiwwarhoaodwoukssl ina wwamhoado  wamasharkii ka ma wataatrifua'],
#  ['common_voice_sw_28662081.mp3',
#   'mdagieahw wwa wanaau o a a misii u namaenaa ameengi nmmyamiijiaka aika aiitia umhini kwassaaaha'],
#  ['common_voice_sw_28662082.mp3',
#   'kana hesimiwanawaa ndlliikkaanan nawaalumthheeriaaamwammtakaiifu'],
#  ['common_voice_sw_28662083.mp3',
#   'si nhemu kubwa ai akaww chini a uin aeaeezea naman ya meegi e chiniya faarraansa nnwuwuje ummanni'],
#  ['common_voice_sw_28662084.mp3',
#   'aasaeiil aya y a ikillea m brereolowa  mna a ma shcha wm  maubwaa y a miwa'],
#  ['common_voice_sw_28662085.mp3',
#   'nnifu unguufsi wa  kb wa aradisadiunia aniu'],
#  ['common_voice_sw_28662086.mp3',
#   'aiiende elie akuung mash y elina kkfumndilsha u'],
#  ['common_voice_sw_28662087.mp3',
#   'i jns m kana ia akwwanza ujengamwanaeeiest uwiloeaaafilka'],
#  ['common_voice_sw_28662088.mp3',
#   'fagoschina lianciahuo sehemukuugo ayavaabuviyeaei et'],
#  ['common_voice_sw_28662089.mp3',
#   'ntatwwa uimim wiinnaya nci  lla jui ya a aci arimunmn csi waiitki'],
#  ['common_voice_sw_28662090.mp3',
#   'pia kouiigpan kna aweza upiganna kwenyyemaa nciiimchia a vu  nun akanaliia'],
#  ['common_voice_sw_28662091.mp3',
#   'tahataklishieizzi ri ko ufwra a mry na kuviiahaevivy tu muuium'],
#  ['common_voice_sw_28662092.mp3',
#   'neenda fouaama aua ya ukshita  uikiina imia a liujii yaahadijriikii'],
#  ['common_voice_sw_28662093.mp3',
#   'khiwa hii kuwaw  addrimmiissiyowana riritkaa ajaa mmhuriaidiiemoka ra asi ayaa akm ngngra'],
#  ['common_voice_sw_28662094.mp3', 'ni mci kuugwa   wtatu wa nchiini'],
#  ['common_voice_sw_28662095.mp3',
#   'iiwaaae ma jweinn aengiiginiwalee a anauinma aliu baeza i ihiopi ay nna ayeed tiz aelyaa alalafu h is aa a aeli'],
#  ['common_voice_sw_28662096.mp3', 'alamaayake nia'],
#  ['common_voice_sw_28662097.mp3',
#   'eatatiwejunayal rangia maja yani npe laoui etchienii ni abuulw uhu'],
#  ['common_voice_sw_28662098.mp3',
#   'kiwamikua aa  kthia ti ma tnee ayawm jaakaik y halimbalimyale'],
#  ['common_voice_sw_28662099.mp3',
#   'iihkkwamna oafaai emn aia na ku miizaniwaetiik aliihihyo iut n us iuaukeieza kk namaa'],
#  ['common_voice_sw_28662100.mp3',
#   'iaa lek wa mu kwwa jiim u ulla uk ueea kktaatieietatuunklay  aaiffu wachen ea ntatt nii ya'],
#  ['common_voice_sw_28662101.mp3', 'wa ama mkia mrefu mnamigu mineiefuu'],
#  ['common_voice_sw_28662103.mp3',
#   'iiililsabbaaushea vta vya levya makaau uuhib yuigyeereeza'],
#  ['common_voice_sw_28662104.mp3',
#   'hi vyo mnuna a aaomu himu o ku enye maenee yabishiihya affwria'],
#  ['common_voice_sw_28662105.mp3', 'kmo so uma mnai a kaikaatiaa mkji'],
#  ['common_voice_sw_28662106.mp3',
#   'djamba amawwalesi aa ahiiii a wasaaniii t iwengii  amweiiysz w wataaznzan i yai'],
#  ['common_voice_sw_28662107.mp3', 'ii ko kwaski rzimi ni mwa njchii'],
#  ['common_voice_sw_28662108.mp3', 'cnbjannkcoo jaconca na cffr ajit'],
#  ['common_voice_sw_28662116.mp3', 'fu maatei inieenreu zaid yamnya mm'],
#  ['common_voice_sw_28662814.mp3',
#   'kwa k waida w ahuff a niakahadi mwa mwhoi ussikoummasho oni dwa ma ah uchiao wa nzeodi mwa k uriiiit'],
#  ['common_voice_sw_28662815.mp3', 'ani injotohn unnyevu aangaa niju'],
#  ['common_voice_sw_28662816.mp3', 'mmjiid huu nmdo gouna itao ia ndefu'],
#  ['common_voice_sw_28662817.mp3',
#   'aliizaliliwa a laatiaka atflanmijia ajirya ua tarl ant sa a khuishijiai'],
#  ['common_voice_sw_28662818.mp3', 'ji na y rasmii ja mimhuri ya imam'],
#  ['common_voice_sw_28662824.mp3',
#   'mwana mi gwgugnmi irfuuna chhi oureffuna ana aa akwah  bguja'],
#  ['common_voice_sw_28662826.mp3',
#   'mdiuz ze himu asihhiiihitina wea utidiiwa n h kuo m vlewa go atuajimdogog'],
#  ['common_voice_sw_28662827.mp3',
#   'mmaenaleo   h a aioudd waae eya kudbaaiiliishwkw maaa auha klaajunmuishshhha'],
#  ['common_voice_sw_28662831.mp3',
#   'ha araa mnjingiaili yo  usaubaibishshwaan adja dau uw hydv hiioy'],
#  ['common_voice_sw_28662835.mp3',
#   'mupennziai mkuuwa wa usaw n avitaawuhao wuva a awu yaausiahaa uugozvna uch bb'],
#  ['common_voice_sw_28662851.mp3',
#   'ku hiriuwa na vrithwa aujiiawaoi  nkuhu wahiimnina  affikka'],
#  ['common_voice_sw_28662853.mp3',
#   'mochi kutaka dgavriivyi wandah anavyviru vya iumemea vyna oehahkwaafahavvii']]

# %%
df = pd.DataFrame(data, columns=["Path", "Sentence"])
df.to_csv("saved_transcriptions.csv", index=False)
